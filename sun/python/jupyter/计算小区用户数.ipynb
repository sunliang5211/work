# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./location_right2.csv')
usr_df = pd.read_csv('./location.csv')
# Out:
# d:\program files (x86)\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError: 
        pass
    try:
        import unicodedata  
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
    return False

# %%
def str_indexlookup(df):
    list1 = []
    for i in range(df.shape[0]):
        if is_number(df['pre_night_longitude'][i]) and is_number(df['pre_night_latitude'][i]):
            pass
        else:
            list1.append(i)
    return list1

# %%
df_index = [i for i in range(df.shape[0])]
str_index = str_indexlookup(usr_df)
num_list = list(set(df_index)-set(str_index))

# %%
df = df.loc[num_list]
# Out:
#                                phone_no pre_night_longitude pre_night_latitude
# 0        dacp::iCaemeHDkReEedxoFY8CKA==           114.29317           30.58431
# 1        dacp::omHzmsDjxEzn1TiqnCg++A==         114.2095327        30.63876685
# 3        dacp::jW4NZD1cj/IAdsdOiXQ19Q==           114.26417           30.54272
# 4        dacp::Fu0HBEX0sweJcB2krcnVVg==           114.22101           30.65777
# 5        dacp::yCiL++q3zlEmMubqIZwsMA==          114.189865           30.61558
# 7        dacp::J/xLX5F4/S0x8pqIqILVFw==           114.29131           30.66294
# 8        dacp::G7Yc+2rn+Z7QKqmAuyL/wQ==           108.69599           30.46545
# 9        dacp::1EkfHQl7R7uhBqmsoRTtuw==           114.27121           30.56483
# 10       dacp::aFJ47KCB9tqoIiAlTGohUw==           114.27212          30.578583
# 11       dacp::OhNRFE4xHw4V/y9ZyONECQ==           114.38821           30.57818
# 12       dacp::sXEo9c+N+z+FBz/A9QTtnw==           114.34574          30.810911
# ...

# %%
for i in range(0,usr_df.shape[0]):
    test_df = usr_df[(usr_df.pre_night_longitude>df['west'][i])&
            (usr_df.pre_night_longitude<df['east'][i])&
            (usr_df.pre_night_latitude<df['north'][i])&
            (usr_df.pre_night_latitude>df['south'][i])]
    xqdf['usr_count'][i] = test_df.shape[0]
