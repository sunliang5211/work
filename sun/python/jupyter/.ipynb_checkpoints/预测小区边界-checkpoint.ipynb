# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt  
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %%
jwddf = pd.read_csv('D:/data/sun/dbscan/jwd_all.csv')
jwddf_groupby = jwddf.groupby(by = 'xq_code')
xq_codes = list(jwddf_groupby.groups.keys())

xqwz = pd.DataFrame({'xq_code':'','east_longitude':'','west_longitude':'','north_latitude':'','south_latitude':''},pd.Index(range(1)))
xq_code_list = []
pre_night_longitude_max_list = []
pre_night_longitude_min_list = []
pre_night_latitude_max_list = []
pre_night_latitude_min_list = []

# %%
def showAllPointImage(jwd,xq_code):
    plt.scatter(jwd['pre_night_longitude'], jwd['pre_night_latitude'], c="red", marker='.', label=xq_code) 
    plt.xlabel('longitude')  
    plt.ylabel('latitude')  
    plt.legend(loc=2)  
    plt.show() 
    
def showCalPointImage(test_df,xq_code):
    plt.scatter(test_df['pre_night_longitude'], test_df['pre_night_latitude'], c="red", marker='.', label=xq_code) 
    plt.xlabel('longitude')  
    plt.ylabel('latitude')  
    plt.legend(loc=2)  
    plt.show() 
    
def showClusterImage(core_member,non_core_member,noise_member,n_clusters_):
    plt.plot(core_member['pre_night_longitude'], core_member['pre_night_latitude'], '+', markersize=6)
    plt.plot(non_core_member['pre_night_longitude'], non_core_member['pre_night_latitude'], '^', markersize=6)
    plt.plot(noise_member['pre_night_longitude'], noise_member['pre_night_latitude'], '.', markersize=6)
    plt.title('Estimated number of clusters: %d' % n_clusters_)
    plt.show()
    
def showMemberImage(xy,xq_code):
    plt.scatter(xy['pre_night_longitude'], xy['pre_night_latitude'], c="red", marker='.', label=xq_code) 
    plt.xlabel('longitude')  
    plt.ylabel('latitude')  
    plt.legend(loc=2)  
    plt.show() 
    
def calMedian(jwd):
    longitude_zws = jwd['pre_night_longitude'].median()
    latitude_zws = jwd['pre_night_latitude'].median()
    return longitude_zws,latitude_zws
    
def calMean(jwd):
    longitude_pjs = jwd['pre_night_longitude'].mean()
    latitude_pjs = jwd['pre_night_latitude'].mean()
    return longitude_pjs,latitude_pjs

def filterExcepValues(jwd,xq_code):
    longitude_zws,latitude_zws = calMedian(jwd)
    test_df = jwd[(jwd.pre_night_longitude > longitude_zws - 0.025) &
        (jwd.pre_night_longitude < longitude_zws + 0.025) &
        (jwd.pre_night_latitude > latitude_zws - 0.025) &
        (jwd.pre_night_latitude < latitude_zws + 0.025)]
    
    excep_num = jwd.shape[0] - test_df.shape[0]
    print('xq_code：',xq_code ,':全部数据点：',jwd.shape[0],'个：可用数据点：',test_df.shape[0],'个：异常数据点:',excep_num,'个')
    return test_df

def dbscan(test_df,eps1,min_samples1):
    db = DBSCAN(eps=eps1, min_samples=min_samples1).fit(test_df[['pre_night_longitude','pre_night_latitude']])
    labels = db.labels_
    #计算簇个数
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    return db,n_clusters_,labels

# %%
i = 0
for xq_code in xq_codes:
    i += 1
    print("当前计算第",i,"个小区")
    jwd = jwddf.loc[jwddf['xq_code']==xq_code]
    
    #展示全部用户位置分布
    #showAllPointImage(jwd,xq_code)
    
    #剔除异常值
    test_df = filterExcepValues(jwd,xq_code)
    
    #展示参与计算的用户的位置分布
    #showCalPointImage(test_df,xq_code)

    if test_df.shape[0] != 0:
        db,n_clusters_,labels = dbscan(test_df,0.001,round(test_df.shape[0] * 0.4))
        
        if n_clusters_ == 1:
            core_samples_mask = np.zeros_like(labels, dtype=bool)
            #核心点
            core_samples_mask[db.core_sample_indices_] = True
            #成员点
            class_member_mask = (labels == 0)
            #噪声点
            noise_member_mask = (labels == -1)
            
            core_member = test_df[class_member_mask & core_samples_mask]
            non_core_member = test_df[class_member_mask & ~core_samples_mask]
            class_member = test_df[class_member_mask]
            noise_member = test_df[noise_member_mask]
            
            
            #展示簇分布
            #showClusterImage(core_member,non_core_member,noise_member,n_clusters_)
            #展示成员点分布
            #showMemberImage(class_member,xq_code)
            
            print('xq_code：',xq_code,',计算点数量：',test_df.shape[0],',成员点数量：',class_member.shape[0],',核心点数量：',core_member.shape[0],',非核心点数量：',non_core_member.shape[0],',噪音点数量：',noise_member.shape[0])
            print('xq_code：',xq_code,class_member['pre_night_longitude'].max(),class_member['pre_night_longitude'].min(),class_member['pre_night_latitude'].max(),class_member['pre_night_latitude'].min()) 
            
            east = class_member['pre_night_longitude'].max()
            west = class_member['pre_night_longitude'].min()
            north = class_member['pre_night_latitude'].max()
            south = class_member['pre_night_latitude'].min()
            
            if (east - west) > 0.0005 and (north - south) > 0.0005:
                xq_code_list.append(xq_code)
                pre_night_longitude_max_list.append(east)
                pre_night_longitude_min_list.append(west)
                pre_night_latitude_max_list.append(north)
                pre_night_latitude_min_list.append(south)
            else:
                pass
                #print('xq_code：',xq_code ,'小区范围大小，重新计算')

        else:
            pass
            #print('xq_code：',xq_code ,'计算簇个数为',n_clusters_,'个，稍后计算！')
            
    else:
        pass
        #print('xq_code：',xq_code ,':可用数据点为',test_df.shape[0],'个，稍后计算！')
# Out:
# 当前计算第 1 个小区
# xq_code： BUSINESS_COMMUNITY-0000000054995ac90154aa61edf80042 :全部数据点： 84 个：可用数据点： 63 个：异常数据点: 21 个
# 当前计算第 2 个小区
# xq_code： BUSINESS_COMMUNITY-141450066916 :全部数据点： 139 个：可用数据点： 79 个：异常数据点: 60 个
# xq_code： BUSINESS_COMMUNITY-141450066916 ,计算点数量： 79 ,成员点数量： 34 ,核心点数量： 34 ,非核心点数量： 0 ,噪音点数量： 45
# xq_code： BUSINESS_COMMUNITY-141450066916 110.42327 110.42327 32.978970000000004 32.978970000000004
# 当前计算第 3 个小区
# xq_code： BUSINESS_COMMUNITY-141450067347 :全部数据点： 86 个：可用数据点： 64 个：异常数据点: 22 个
# 当前计算第 4 个小区
# xq_code： BUSINESS_COMMUNITY-141450067362 :全部数据点： 94 个：可用数据点： 61 个：异常数据点: 33 个
# 当前计算第 5 个小区
# xq_code： BUSINESS_COMMUNITY-141450067369 :全部数据点： 64 个：可用数据点： 49 个：异常数据点: 15 个
# 当前计算第 6 个小区
# xq_code： BUSINESS_COMMUNITY-141450067372 :全部数据点： 96 个：可用数据点： 73 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450067372 ,计算点数量： 73 ,成员点数量： 40 ,核心点数量： 40 ,非核心点数量： 0 ,噪音点数量： 33
# xq_code： BUSINESS_COMMUNITY-141450067372 113.814705 113.814705 29.239760999999998 29.239760999999998
# 当前计算第 7 个小区
# xq_code： BUSINESS_COMMUNITY-141450067384 :全部数据点： 85 个：可用数据点： 57 个：异常数据点: 28 个
# 当前计算第 8 个小区
# xq_code： BUSINESS_COMMUNITY-141450067390 :全部数据点： 62 个：可用数据点： 39 个：异常数据点: 23 个
# 当前计算第 9 个小区
# xq_code： BUSINESS_COMMUNITY-141450067407 :全部数据点： 60 个：可用数据点： 50 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-141450067407 ,计算点数量： 50 ,成员点数量： 20 ,核心点数量： 20 ,非核心点数量： 0 ,噪音点数量： 30
# xq_code： BUSINESS_COMMUNITY-141450067407 113.81038999999998 113.81036 29.247590000000002 29.24755
# 当前计算第 10 个小区
# xq_code： BUSINESS_COMMUNITY-141450067427 :全部数据点： 70 个：可用数据点： 46 个：异常数据点: 24 个
# 当前计算第 11 个小区
# xq_code： BUSINESS_COMMUNITY-141450067471 :全部数据点： 51 个：可用数据点： 42 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141450067471 ,计算点数量： 42 ,成员点数量： 21 ,核心点数量： 21 ,非核心点数量： 0 ,噪音点数量： 21
# xq_code： BUSINESS_COMMUNITY-141450067471 113.88648 113.88630731 29.72587842 29.725001000000002
# 当前计算第 12 个小区
# xq_code： BUSINESS_COMMUNITY-141450067513 :全部数据点： 70 个：可用数据点： 50 个：异常数据点: 20 个
# 当前计算第 13 个小区
# xq_code： BUSINESS_COMMUNITY-141450067537 :全部数据点： 58 个：可用数据点： 41 个：异常数据点: 17 个
# 当前计算第 14 个小区
# xq_code： BUSINESS_COMMUNITY-141450067538 :全部数据点： 69 个：可用数据点： 55 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450067538 ,计算点数量： 55 ,成员点数量： 35 ,核心点数量： 34 ,非核心点数量： 1 ,噪音点数量： 20
# xq_code： BUSINESS_COMMUNITY-141450067538 113.874794 113.87425379999999 29.70269044 29.701694
# 当前计算第 15 个小区
# xq_code： BUSINESS_COMMUNITY-141450067551 :全部数据点： 77 个：可用数据点： 51 个：异常数据点: 26 个
# 当前计算第 16 个小区
# xq_code： BUSINESS_COMMUNITY-141450067555 :全部数据点： 76 个：可用数据点： 56 个：异常数据点: 20 个
# 当前计算第 17 个小区
# xq_code： BUSINESS_COMMUNITY-141450067587 :全部数据点： 60 个：可用数据点： 39 个：异常数据点: 21 个
# 当前计算第 18 个小区
# xq_code： BUSINESS_COMMUNITY-141450067589 :全部数据点： 53 个：可用数据点： 41 个：异常数据点: 12 个
# 当前计算第 19 个小区
# xq_code： BUSINESS_COMMUNITY-141450067603 :全部数据点： 57 个：可用数据点： 33 个：异常数据点: 24 个
# 当前计算第 20 个小区
# xq_code： BUSINESS_COMMUNITY-141450067607 :全部数据点： 53 个：可用数据点： 34 个：异常数据点: 19 个
# 当前计算第 21 个小区
# xq_code： BUSINESS_COMMUNITY-141450067614 :全部数据点： 99 个：可用数据点： 53 个：异常数据点: 46 个
# xq_code： BUSINESS_COMMUNITY-141450067614 ,计算点数量： 53 ,成员点数量： 28 ,核心点数量： 27 ,非核心点数量： 1 ,噪音点数量： 25
# xq_code： BUSINESS_COMMUNITY-141450067614 113.91837218 113.91806000000001 29.72697866 29.72519
# 当前计算第 22 个小区
# xq_code： BUSINESS_COMMUNITY-141450067630 :全部数据点： 51 个：可用数据点： 24 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-141450067630 ,计算点数量： 24 ,成员点数量： 10 ,核心点数量： 10 ,非核心点数量： 0 ,噪音点数量： 14
# xq_code： BUSINESS_COMMUNITY-141450067630 113.931595 113.93094763 29.73301385 29.732613
# 当前计算第 23 个小区
# xq_code： BUSINESS_COMMUNITY-141450067792 :全部数据点： 58 个：可用数据点： 33 个：异常数据点: 25 个
# 当前计算第 24 个小区
# xq_code： BUSINESS_COMMUNITY-141450067971 :全部数据点： 71 个：可用数据点： 49 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450067971 ,计算点数量： 49 ,成员点数量： 27 ,核心点数量： 24 ,非核心点数量： 3 ,噪音点数量： 22
# xq_code： BUSINESS_COMMUNITY-141450067971 113.91557 113.91516484 29.97326431 29.97196
# 当前计算第 25 个小区
# xq_code： BUSINESS_COMMUNITY-141450067972 :全部数据点： 56 个：可用数据点： 48 个：异常数据点: 8 个
# 当前计算第 26 个小区
# xq_code： BUSINESS_COMMUNITY-141450068127 :全部数据点： 164 个：可用数据点： 110 个：异常数据点: 54 个
# xq_code： BUSINESS_COMMUNITY-141450068127 ,计算点数量： 110 ,成员点数量： 80 ,核心点数量： 80 ,非核心点数量： 0 ,噪音点数量： 30
# xq_code： BUSINESS_COMMUNITY-141450068127 113.28152 113.28148 31.880271999999998 31.88027
# 当前计算第 27 个小区
# xq_code： BUSINESS_COMMUNITY-141450068148 :全部数据点： 86 个：可用数据点： 62 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450068148 ,计算点数量： 62 ,成员点数量： 25 ,核心点数量： 25 ,非核心点数量： 0 ,噪音点数量： 37
# xq_code： BUSINESS_COMMUNITY-141450068148 113.33377 113.33377 31.716209999999997 31.716209999999997
# 当前计算第 28 个小区
# xq_code： BUSINESS_COMMUNITY-141450068158 :全部数据点： 70 个：可用数据点： 46 个：异常数据点: 24 个
# 当前计算第 29 个小区
# xq_code： BUSINESS_COMMUNITY-141450068163 :全部数据点： 135 个：可用数据点： 113 个：异常数据点: 22 个
# 当前计算第 30 个小区
# xq_code： BUSINESS_COMMUNITY-141450068245 :全部数据点： 46 个：可用数据点： 26 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450068245 ,计算点数量： 26 ,成员点数量： 12 ,核心点数量： 12 ,非核心点数量： 0 ,噪音点数量： 14
# xq_code： BUSINESS_COMMUNITY-141450068245 113.81643000000001 113.81602 31.611944 31.61143
# 当前计算第 31 个小区
# xq_code： BUSINESS_COMMUNITY-141450068488 :全部数据点： 146 个：可用数据点： 104 个：异常数据点: 42 个
# 当前计算第 32 个小区
# xq_code： BUSINESS_COMMUNITY-141450068787 :全部数据点： 27 个：可用数据点： 22 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450068787 ,计算点数量： 22 ,成员点数量： 12 ,核心点数量： 12 ,非核心点数量： 0 ,噪音点数量： 10
# xq_code： BUSINESS_COMMUNITY-141450068787 113.36568 113.36568 31.713290999999998 31.713290999999998
# 当前计算第 33 个小区
# xq_code： BUSINESS_COMMUNITY-141450068794 :全部数据点： 67 个：可用数据点： 54 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450068794 ,计算点数量： 54 ,成员点数量： 25 ,核心点数量： 25 ,非核心点数量： 0 ,噪音点数量： 29
# xq_code： BUSINESS_COMMUNITY-141450068794 113.36482 113.36469 31.71746 31.717177000000003
# 当前计算第 34 个小区
# xq_code： BUSINESS_COMMUNITY-141450069533 :全部数据点： 118 个：可用数据点： 88 个：异常数据点: 30 个
# 当前计算第 35 个小区
# xq_code： BUSINESS_COMMUNITY-141450069613 :全部数据点： 117 个：可用数据点： 85 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450069613 ,计算点数量： 85 ,成员点数量： 49 ,核心点数量： 49 ,非核心点数量： 0 ,噪音点数量： 36
# xq_code： BUSINESS_COMMUNITY-141450069613 113.37848000000001 113.37848000000001 31.636390000000002 31.636390000000002
# 当前计算第 36 个小区
# xq_code： BUSINESS_COMMUNITY-141450069770 :全部数据点： 151 个：可用数据点： 129 个：异常数据点: 22 个
# 当前计算第 37 个小区
# xq_code： BUSINESS_COMMUNITY-141450069780 :全部数据点： 85 个：可用数据点： 65 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450069780 ,计算点数量： 65 ,成员点数量： 38 ,核心点数量： 38 ,非核心点数量： 0 ,噪音点数量： 27
# xq_code： BUSINESS_COMMUNITY-141450069780 112.19604 112.19599 31.042920000000002 31.042696999999997
# 当前计算第 38 个小区
# xq_code： BUSINESS_COMMUNITY-141450069821 :全部数据点： 90 个：可用数据点： 74 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450069821 ,计算点数量： 74 ,成员点数量： 32 ,核心点数量： 32 ,非核心点数量： 0 ,噪音点数量： 42
# xq_code： BUSINESS_COMMUNITY-141450069821 112.19793700000001 112.19768 31.036890000000003 31.036859999999997
# 当前计算第 39 个小区
# xq_code： BUSINESS_COMMUNITY-141450069833 :全部数据点： 46 个：可用数据点： 41 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450069833 ,计算点数量： 41 ,成员点数量： 16 ,核心点数量： 16 ,非核心点数量： 0 ,噪音点数量： 25
# xq_code： BUSINESS_COMMUNITY-141450069833 112.19316 112.19316 31.041475 31.041475
# 当前计算第 40 个小区
# xq_code： BUSINESS_COMMUNITY-141450069834 :全部数据点： 48 个：可用数据点： 39 个：异常数据点: 9 个
# 当前计算第 41 个小区
# xq_code： BUSINESS_COMMUNITY-141450069931 :全部数据点： 91 个：可用数据点： 71 个：异常数据点: 20 个
# 当前计算第 42 个小区
# xq_code： BUSINESS_COMMUNITY-141450069970 :全部数据点： 53 个：可用数据点： 32 个：异常数据点: 21 个
# 当前计算第 43 个小区
# xq_code： BUSINESS_COMMUNITY-141450070018 :全部数据点： 110 个：可用数据点： 88 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450070018 ,计算点数量： 88 ,成员点数量： 38 ,核心点数量： 38 ,非核心点数量： 0 ,噪音点数量： 50
# xq_code： BUSINESS_COMMUNITY-141450070018 112.18542 112.18536999999999 30.973398 30.973368
# 当前计算第 44 个小区
# xq_code： BUSINESS_COMMUNITY-141450070021 :全部数据点： 85 个：可用数据点： 53 个：异常数据点: 32 个
# 当前计算第 45 个小区
# xq_code： BUSINESS_COMMUNITY-141450070025 :全部数据点： 129 个：可用数据点： 93 个：异常数据点: 36 个
# xq_code： BUSINESS_COMMUNITY-141450070025 ,计算点数量： 93 ,成员点数量： 40 ,核心点数量： 40 ,非核心点数量： 0 ,噪音点数量： 53
# xq_code： BUSINESS_COMMUNITY-141450070025 112.18811000000001 112.18811000000001 30.988049 30.988049
# 当前计算第 46 个小区
# xq_code： BUSINESS_COMMUNITY-141450070058 :全部数据点： 51 个：可用数据点： 46 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450070058 ,计算点数量： 46 ,成员点数量： 29 ,核心点数量： 29 ,非核心点数量： 0 ,噪音点数量： 17
# xq_code： BUSINESS_COMMUNITY-141450070058 112.20913999999999 112.20910500000001 31.034065000000002 31.034024
# 当前计算第 47 个小区
# xq_code： BUSINESS_COMMUNITY-141450070075 :全部数据点： 128 个：可用数据点： 106 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450070075 ,计算点数量： 106 ,成员点数量： 58 ,核心点数量： 58 ,非核心点数量： 0 ,噪音点数量： 48
# xq_code： BUSINESS_COMMUNITY-141450070075 112.21548999999999 112.2153 31.041521000000003 31.040728
# 当前计算第 48 个小区
# xq_code： BUSINESS_COMMUNITY-141450070102 :全部数据点： 139 个：可用数据点： 112 个：异常数据点: 27 个
# 当前计算第 49 个小区
# xq_code： BUSINESS_COMMUNITY-141450070131 :全部数据点： 105 个：可用数据点： 66 个：异常数据点: 39 个
# 当前计算第 50 个小区
# xq_code： BUSINESS_COMMUNITY-141450070151 :全部数据点： 154 个：可用数据点： 133 个：异常数据点: 21 个
# 当前计算第 51 个小区
# xq_code： BUSINESS_COMMUNITY-141450070187 :全部数据点： 123 个：可用数据点： 90 个：异常数据点: 33 个
# 当前计算第 52 个小区
# xq_code： BUSINESS_COMMUNITY-141450070298 :全部数据点： 53 个：可用数据点： 40 个：异常数据点: 13 个
# 当前计算第 53 个小区
# xq_code： BUSINESS_COMMUNITY-141450070420 :全部数据点： 32 个：可用数据点： 28 个：异常数据点: 4 个
# 当前计算第 54 个小区
# xq_code： BUSINESS_COMMUNITY-141450070423 :全部数据点： 98 个：可用数据点： 76 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450070423 ,计算点数量： 76 ,成员点数量： 34 ,核心点数量： 1 ,非核心点数量： 33 ,噪音点数量： 42
# xq_code： BUSINESS_COMMUNITY-141450070423 112.19731000000002 112.19695 31.03465 31.033375
# 当前计算第 55 个小区
# xq_code： BUSINESS_COMMUNITY-141450070464 :全部数据点： 78 个：可用数据点： 60 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450070464 ,计算点数量： 60 ,成员点数量： 36 ,核心点数量： 36 ,非核心点数量： 0 ,噪音点数量： 24
# xq_code： BUSINESS_COMMUNITY-141450070464 112.18911000000001 112.188395 30.959143 30.959059999999997
# 当前计算第 56 个小区
# xq_code： BUSINESS_COMMUNITY-141450070520 :全部数据点： 48 个：可用数据点： 40 个：异常数据点: 8 个
# 当前计算第 57 个小区
# xq_code： BUSINESS_COMMUNITY-141450070604 :全部数据点： 90 个：可用数据点： 70 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450070604 ,计算点数量： 70 ,成员点数量： 39 ,核心点数量： 39 ,非核心点数量： 0 ,噪音点数量： 31
# xq_code： BUSINESS_COMMUNITY-141450070604 113.11362 113.11358200000001 31.02314 31.023064
# 当前计算第 58 个小区
# xq_code： BUSINESS_COMMUNITY-141450070627 :全部数据点： 78 个：可用数据点： 70 个：异常数据点: 8 个
# 当前计算第 59 个小区
# xq_code： BUSINESS_COMMUNITY-141450070633 :全部数据点： 68 个：可用数据点： 55 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450070633 ,计算点数量： 55 ,成员点数量： 26 ,核心点数量： 26 ,非核心点数量： 0 ,噪音点数量： 29
# xq_code： BUSINESS_COMMUNITY-141450070633 112.562675 112.56261 30.702268 30.702209999999997
# 当前计算第 60 个小区
# xq_code： BUSINESS_COMMUNITY-141450070638 :全部数据点： 67 个：可用数据点： 59 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450070638 ,计算点数量： 59 ,成员点数量： 26 ,核心点数量： 26 ,非核心点数量： 0 ,噪音点数量： 33
# xq_code： BUSINESS_COMMUNITY-141450070638 112.56147 112.561434 30.675154 30.675085
# 当前计算第 61 个小区
# xq_code： BUSINESS_COMMUNITY-141450070690 :全部数据点： 69 个：可用数据点： 41 个：异常数据点: 28 个
# xq_code： BUSINESS_COMMUNITY-141450070690 ,计算点数量： 41 ,成员点数量： 19 ,核心点数量： 19 ,非核心点数量： 0 ,噪音点数量： 22
# xq_code： BUSINESS_COMMUNITY-141450070690 112.60382 112.60343 31.17241 31.17182
# 当前计算第 62 个小区
# xq_code： BUSINESS_COMMUNITY-141450070701 :全部数据点： 31 个：可用数据点： 24 个：异常数据点: 7 个
# 当前计算第 63 个小区
# xq_code： BUSINESS_COMMUNITY-141450070704 :全部数据点： 60 个：可用数据点： 46 个：异常数据点: 14 个
# 当前计算第 64 个小区
# xq_code： BUSINESS_COMMUNITY-141450070715 :全部数据点： 48 个：可用数据点： 39 个：异常数据点: 9 个
# 当前计算第 65 个小区
# xq_code： BUSINESS_COMMUNITY-141450070762 :全部数据点： 94 个：可用数据点： 77 个：异常数据点: 17 个
# 当前计算第 66 个小区
# xq_code： BUSINESS_COMMUNITY-141450070802 :全部数据点： 38 个：可用数据点： 25 个：异常数据点: 13 个
# 当前计算第 67 个小区
# xq_code： BUSINESS_COMMUNITY-141450070803 :全部数据点： 45 个：可用数据点： 38 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450070803 ,计算点数量： 38 ,成员点数量： 27 ,核心点数量： 27 ,非核心点数量： 0 ,噪音点数量： 11
# xq_code： BUSINESS_COMMUNITY-141450070803 112.56487 112.56487 30.696886 30.696886
# 当前计算第 68 个小区
# xq_code： BUSINESS_COMMUNITY-141450070833 :全部数据点： 29 个：可用数据点： 20 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141450070833 ,计算点数量： 20 ,成员点数量： 15 ,核心点数量： 15 ,非核心点数量： 0 ,噪音点数量： 5
# xq_code： BUSINESS_COMMUNITY-141450070833 112.57137 112.57122700000001 31.17006 31.169868
# 当前计算第 69 个小区
# xq_code： BUSINESS_COMMUNITY-141450070841 :全部数据点： 58 个：可用数据点： 42 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450070841 ,计算点数量： 42 ,成员点数量： 26 ,核心点数量： 26 ,非核心点数量： 0 ,噪音点数量： 16
# xq_code： BUSINESS_COMMUNITY-141450070841 112.59508000000001 112.59488999999999 31.17455 31.174118
# 当前计算第 70 个小区
# xq_code： BUSINESS_COMMUNITY-141450070851 :全部数据点： 40 个：可用数据点： 35 个：异常数据点: 5 个
# 当前计算第 71 个小区
# xq_code： BUSINESS_COMMUNITY-141450070864 :全部数据点： 65 个：可用数据点： 58 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450070864 ,计算点数量： 58 ,成员点数量： 36 ,核心点数量： 36 ,非核心点数量： 0 ,噪音点数量： 22
# xq_code： BUSINESS_COMMUNITY-141450070864 112.58466999999999 112.58466999999999 30.7201 30.7201
# 当前计算第 72 个小区
# xq_code： BUSINESS_COMMUNITY-141450070880 :全部数据点： 71 个：可用数据点： 39 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450070880 ,计算点数量： 39 ,成员点数量： 23 ,核心点数量： 23 ,非核心点数量： 0 ,噪音点数量： 16
# xq_code： BUSINESS_COMMUNITY-141450070880 112.38078300000001 112.38072 30.524540000000002 30.524490000000004
# 当前计算第 73 个小区
# xq_code： BUSINESS_COMMUNITY-141450071030 :全部数据点： 92 个：可用数据点： 68 个：异常数据点: 24 个
# 当前计算第 74 个小区
# xq_code： BUSINESS_COMMUNITY-141450071036 :全部数据点： 109 个：可用数据点： 83 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-141450071036 ,计算点数量： 83 ,成员点数量： 49 ,核心点数量： 49 ,非核心点数量： 0 ,噪音点数量： 34
# xq_code： BUSINESS_COMMUNITY-141450071036 112.56943500000001 112.56943500000001 30.698040000000002 30.698040000000002
# 当前计算第 75 个小区
# xq_code： BUSINESS_COMMUNITY-141450071046 :全部数据点： 162 个：可用数据点： 122 个：异常数据点: 40 个
# xq_code： BUSINESS_COMMUNITY-141450071046 ,计算点数量： 122 ,成员点数量： 52 ,核心点数量： 52 ,非核心点数量： 0 ,噪音点数量： 70
# xq_code： BUSINESS_COMMUNITY-141450071046 112.57388 112.57364 30.703415000000003 30.70317
# 当前计算第 76 个小区
# xq_code： BUSINESS_COMMUNITY-141450071096 :全部数据点： 95 个：可用数据点： 78 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450071096 ,计算点数量： 78 ,成员点数量： 50 ,核心点数量： 50 ,非核心点数量： 0 ,噪音点数量： 28
# xq_code： BUSINESS_COMMUNITY-141450071096 113.106669 113.10651000000001 31.031668 31.031640000000003
# 当前计算第 77 个小区
# xq_code： BUSINESS_COMMUNITY-141450071100 :全部数据点： 72 个：可用数据点： 56 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450071100 ,计算点数量： 56 ,成员点数量： 34 ,核心点数量： 34 ,非核心点数量： 0 ,噪音点数量： 22
# xq_code： BUSINESS_COMMUNITY-141450071100 113.10358000000001 113.10358000000001 31.031671999999997 31.031671999999997
# 当前计算第 78 个小区
# xq_code： BUSINESS_COMMUNITY-141450071114 :全部数据点： 174 个：可用数据点： 125 个：异常数据点: 49 个
# xq_code： BUSINESS_COMMUNITY-141450071114 ,计算点数量： 125 ,成员点数量： 59 ,核心点数量： 59 ,非核心点数量： 0 ,噪音点数量： 66
# xq_code： BUSINESS_COMMUNITY-141450071114 112.58181 112.58168 30.695871 30.695837
# 当前计算第 79 个小区
# xq_code： BUSINESS_COMMUNITY-141450071163 :全部数据点： 128 个：可用数据点： 106 个：异常数据点: 22 个
# 当前计算第 80 个小区
# xq_code： BUSINESS_COMMUNITY-141450071171 :全部数据点： 100 个：可用数据点： 77 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450071171 ,计算点数量： 77 ,成员点数量： 37 ,核心点数量： 37 ,非核心点数量： 0 ,噪音点数量： 40
# xq_code： BUSINESS_COMMUNITY-141450071171 113.09889 113.09889 31.033941 31.033941
# 当前计算第 81 个小区
# xq_code： BUSINESS_COMMUNITY-141450071172 :全部数据点： 162 个：可用数据点： 135 个：异常数据点: 27 个
# 当前计算第 82 个小区
# xq_code： BUSINESS_COMMUNITY-141450071290 :全部数据点： 88 个：可用数据点： 68 个：异常数据点: 20 个
# 当前计算第 83 个小区
# xq_code： BUSINESS_COMMUNITY-141450071304 :全部数据点： 148 个：可用数据点： 119 个：异常数据点: 29 个
# 当前计算第 84 个小区
# xq_code： BUSINESS_COMMUNITY-141450071352 :全部数据点： 96 个：可用数据点： 67 个：异常数据点: 29 个
# 当前计算第 85 个小区
# xq_code： BUSINESS_COMMUNITY-141450071360 :全部数据点： 171 个：可用数据点： 132 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-141450071360 ,计算点数量： 132 ,成员点数量： 58 ,核心点数量： 58 ,非核心点数量： 0 ,噪音点数量： 74
# xq_code： BUSINESS_COMMUNITY-141450071360 113.11538 113.11538 31.025059999999996 31.025059999999996
# 当前计算第 86 个小区
# xq_code： BUSINESS_COMMUNITY-141450071472 :全部数据点： 104 个：可用数据点： 78 个：异常数据点: 26 个
# 当前计算第 87 个小区
# xq_code： BUSINESS_COMMUNITY-141450071505 :全部数据点： 51 个：可用数据点： 38 个：异常数据点: 13 个
# 当前计算第 88 个小区
# xq_code： BUSINESS_COMMUNITY-141450071561 :全部数据点： 259 个：可用数据点： 210 个：异常数据点: 49 个
# 当前计算第 89 个小区
# xq_code： BUSINESS_COMMUNITY-141450071595 :全部数据点： 124 个：可用数据点： 82 个：异常数据点: 42 个
# xq_code： BUSINESS_COMMUNITY-141450071595 ,计算点数量： 82 ,成员点数量： 34 ,核心点数量： 34 ,非核心点数量： 0 ,噪音点数量： 48
# xq_code： BUSINESS_COMMUNITY-141450071595 111.47676000000001 111.47676000000001 32.255054 32.255054
# 当前计算第 90 个小区
# xq_code： BUSINESS_COMMUNITY-141450071656 :全部数据点： 108 个：可用数据点： 78 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-141450071656 ,计算点数量： 78 ,成员点数量： 45 ,核心点数量： 45 ,非核心点数量： 0 ,噪音点数量： 33
# xq_code： BUSINESS_COMMUNITY-141450071656 112.12493 112.12493 32.04681 32.04681
# 当前计算第 91 个小区
# xq_code： BUSINESS_COMMUNITY-141450071659 :全部数据点： 144 个：可用数据点： 99 个：异常数据点: 45 个
# xq_code： BUSINESS_COMMUNITY-141450071659 ,计算点数量： 99 ,成员点数量： 44 ,核心点数量： 44 ,非核心点数量： 0 ,噪音点数量： 55
# xq_code： BUSINESS_COMMUNITY-141450071659 112.09823999999999 112.09823999999999 32.05571 32.05571
# 当前计算第 92 个小区
# xq_code： BUSINESS_COMMUNITY-141450071664 :全部数据点： 162 个：可用数据点： 130 个：异常数据点: 32 个
# 当前计算第 93 个小区
# xq_code： BUSINESS_COMMUNITY-141450071665 :全部数据点： 159 个：可用数据点： 125 个：异常数据点: 34 个
# 当前计算第 94 个小区
# xq_code： BUSINESS_COMMUNITY-141450071670 :全部数据点： 46 个：可用数据点： 38 个：异常数据点: 8 个
# 当前计算第 95 个小区
# xq_code： BUSINESS_COMMUNITY-141450071756 :全部数据点： 161 个：可用数据点： 127 个：异常数据点: 34 个
# xq_code： BUSINESS_COMMUNITY-141450071756 ,计算点数量： 127 ,成员点数量： 71 ,核心点数量： 71 ,非核心点数量： 0 ,噪音点数量： 56
# xq_code： BUSINESS_COMMUNITY-141450071756 112.11091 112.11091 32.051075 32.051075
# 当前计算第 96 个小区
# xq_code： BUSINESS_COMMUNITY-141450071763 :全部数据点： 48 个：可用数据点： 30 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450071763 ,计算点数量： 30 ,成员点数量： 16 ,核心点数量： 16 ,非核心点数量： 0 ,噪音点数量： 14
# xq_code： BUSINESS_COMMUNITY-141450071763 112.11171000000002 112.11086 32.042107 32.04188
# 当前计算第 97 个小区
# xq_code： BUSINESS_COMMUNITY-141450071764 :全部数据点： 104 个：可用数据点： 68 个：异常数据点: 36 个
# xq_code： BUSINESS_COMMUNITY-141450071764 ,计算点数量： 68 ,成员点数量： 34 ,核心点数量： 34 ,非核心点数量： 0 ,噪音点数量： 34
# xq_code： BUSINESS_COMMUNITY-141450071764 112.1152 112.1152 32.043853999999996 32.043853999999996
# 当前计算第 98 个小区
# xq_code： BUSINESS_COMMUNITY-141450071770 :全部数据点： 79 个：可用数据点： 65 个：异常数据点: 14 个
# 当前计算第 99 个小区
# xq_code： BUSINESS_COMMUNITY-141450071804 :全部数据点： 97 个：可用数据点： 7 个：异常数据点: 90 个
# xq_code： BUSINESS_COMMUNITY-141450071804 ,计算点数量： 7 ,成员点数量： 3 ,核心点数量： 3 ,非核心点数量： 0 ,噪音点数量： 4
# xq_code： BUSINESS_COMMUNITY-141450071804 112.43198899999999 112.43198899999999 32.106542 32.106542
# 当前计算第 100 个小区
# xq_code： BUSINESS_COMMUNITY-141450071821 :全部数据点： 65 个：可用数据点： 33 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450071821 ,计算点数量： 33 ,成员点数量： 26 ,核心点数量： 26 ,非核心点数量： 0 ,噪音点数量： 7
# xq_code： BUSINESS_COMMUNITY-141450071821 111.27877 111.27851299999999 31.83434 31.834304
# 当前计算第 101 个小区
# xq_code： BUSINESS_COMMUNITY-141450071853 :全部数据点： 250 个：可用数据点： 196 个：异常数据点: 54 个
# xq_code： BUSINESS_COMMUNITY-141450071853 ,计算点数量： 196 ,成员点数量： 78 ,核心点数量： 19 ,非核心点数量： 59 ,噪音点数量： 118
# xq_code： BUSINESS_COMMUNITY-141450071853 112.09827 112.097595 32.052665999999995 32.051823
# 当前计算第 102 个小区
# xq_code： BUSINESS_COMMUNITY-141450071856 :全部数据点： 45 个：可用数据点： 37 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450071856 ,计算点数量： 37 ,成员点数量： 16 ,核心点数量： 16 ,非核心点数量： 0 ,噪音点数量： 21
# xq_code： BUSINESS_COMMUNITY-141450071856 112.11321000000001 112.11321000000001 32.05366 32.05366
# 当前计算第 103 个小区
# xq_code： BUSINESS_COMMUNITY-141450071940 :全部数据点： 70 个：可用数据点： 59 个：异常数据点: 11 个
# 当前计算第 104 个小区
# xq_code： BUSINESS_COMMUNITY-141450071984 :全部数据点： 129 个：可用数据点： 84 个：异常数据点: 45 个
# 当前计算第 105 个小区
# xq_code： BUSINESS_COMMUNITY-141450072000 :全部数据点： 65 个：可用数据点： 48 个：异常数据点: 17 个
# 当前计算第 106 个小区
# xq_code： BUSINESS_COMMUNITY-141450072025 :全部数据点： 61 个：可用数据点： 47 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450072025 ,计算点数量： 47 ,成员点数量： 29 ,核心点数量： 29 ,非核心点数量： 0 ,噪音点数量： 18
# xq_code： BUSINESS_COMMUNITY-141450072025 112.13546000000001 112.13533000000001 32.03549 32.035247999999996
# 当前计算第 107 个小区
# xq_code： BUSINESS_COMMUNITY-141450072031 :全部数据点： 105 个：可用数据点： 75 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-141450072031 ,计算点数量： 75 ,成员点数量： 45 ,核心点数量： 45 ,非核心点数量： 0 ,噪音点数量： 30
# xq_code： BUSINESS_COMMUNITY-141450072031 112.13543 112.13543 32.04177 32.04177
# 当前计算第 108 个小区
# xq_code： BUSINESS_COMMUNITY-141450072086 :全部数据点： 65 个：可用数据点： 48 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450072086 ,计算点数量： 48 ,成员点数量： 24 ,核心点数量： 24 ,非核心点数量： 0 ,噪音点数量： 24
# xq_code： BUSINESS_COMMUNITY-141450072086 112.25341 112.25341 31.7031 31.7031
# 当前计算第 109 个小区
# xq_code： BUSINESS_COMMUNITY-141450072098 :全部数据点： 53 个：可用数据点： 38 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450072098 ,计算点数量： 38 ,成员点数量： 19 ,核心点数量： 19 ,非核心点数量： 0 ,噪音点数量： 19
# xq_code： BUSINESS_COMMUNITY-141450072098 112.149254 112.14889 32.052094 32.05145
# 当前计算第 110 个小区
# xq_code： BUSINESS_COMMUNITY-141450072099 :全部数据点： 169 个：可用数据点： 131 个：异常数据点: 38 个
# xq_code： BUSINESS_COMMUNITY-141450072099 ,计算点数量： 131 ,成员点数量： 90 ,核心点数量： 76 ,非核心点数量： 14 ,噪音点数量： 41
# xq_code： BUSINESS_COMMUNITY-141450072099 112.148482 112.1467 32.05092 32.049723
# 当前计算第 111 个小区
# xq_code： BUSINESS_COMMUNITY-141450072119 :全部数据点： 127 个：可用数据点： 103 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450072119 ,计算点数量： 103 ,成员点数量： 63 ,核心点数量： 63 ,非核心点数量： 0 ,噪音点数量： 40
# xq_code： BUSINESS_COMMUNITY-141450072119 112.14399999999999 112.14399999999999 32.038517 32.038517
# 当前计算第 112 个小区
# xq_code： BUSINESS_COMMUNITY-141450072133 :全部数据点： 132 个：可用数据点： 93 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-141450072133 ,计算点数量： 93 ,成员点数量： 50 ,核心点数量： 45 ,非核心点数量： 5 ,噪音点数量： 43
# xq_code： BUSINESS_COMMUNITY-141450072133 112.13649 112.13502 32.04824 32.04793
# 当前计算第 113 个小区
# xq_code： BUSINESS_COMMUNITY-141450072248 :全部数据点： 63 个：可用数据点： 46 个：异常数据点: 17 个
# 当前计算第 114 个小区
# xq_code： BUSINESS_COMMUNITY-141450072257 :全部数据点： 65 个：可用数据点： 51 个：异常数据点: 14 个
# 当前计算第 115 个小区
# xq_code： BUSINESS_COMMUNITY-141450072327 :全部数据点： 57 个：可用数据点： 44 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450072327 ,计算点数量： 44 ,成员点数量： 21 ,核心点数量： 21 ,非核心点数量： 0 ,噪音点数量： 23
# xq_code： BUSINESS_COMMUNITY-141450072327 112.15732 112.15717 32.05236 32.05205
# 当前计算第 116 个小区
# xq_code： BUSINESS_COMMUNITY-141450072337 :全部数据点： 69 个：可用数据点： 49 个：异常数据点: 20 个
# 当前计算第 117 个小区
# xq_code： BUSINESS_COMMUNITY-141450072338 :全部数据点： 96 个：可用数据点： 48 个：异常数据点: 48 个
# 当前计算第 118 个小区
# xq_code： BUSINESS_COMMUNITY-141450072346 :全部数据点： 116 个：可用数据点： 85 个：异常数据点: 31 个
# xq_code： BUSINESS_COMMUNITY-141450072346 ,计算点数量： 85 ,成员点数量： 53 ,核心点数量： 53 ,非核心点数量： 0 ,噪音点数量： 32
# xq_code： BUSINESS_COMMUNITY-141450072346 112.12959 112.12895 32.07582 32.075798
# 当前计算第 119 个小区
# xq_code： BUSINESS_COMMUNITY-141450072349 :全部数据点： 68 个：可用数据点： 43 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450072349 ,计算点数量： 43 ,成员点数量： 29 ,核心点数量： 29 ,非核心点数量： 0 ,噪音点数量： 14
# xq_code： BUSINESS_COMMUNITY-141450072349 112.12959 112.12895 32.07582 32.075798
# 当前计算第 120 个小区
# xq_code： BUSINESS_COMMUNITY-141450072373 :全部数据点： 63 个：可用数据点： 51 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450072373 ,计算点数量： 51 ,成员点数量： 32 ,核心点数量： 32 ,非核心点数量： 0 ,噪音点数量： 19
# xq_code： BUSINESS_COMMUNITY-141450072373 111.66966000000001 111.669614 32.377778 32.37771
# 当前计算第 121 个小区
# xq_code： BUSINESS_COMMUNITY-141450072543 :全部数据点： 69 个：可用数据点： 54 个：异常数据点: 15 个
# 当前计算第 122 个小区
# xq_code： BUSINESS_COMMUNITY-141450072547 :全部数据点： 64 个：可用数据点： 45 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450072547 ,计算点数量： 45 ,成员点数量： 19 ,核心点数量： 19 ,非核心点数量： 0 ,噪音点数量： 26
# xq_code： BUSINESS_COMMUNITY-141450072547 112.16938 112.16938 32.04848 32.04848
# 当前计算第 123 个小区
# xq_code： BUSINESS_COMMUNITY-141450072548 :全部数据点： 81 个：可用数据点： 56 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450072548 ,计算点数量： 56 ,成员点数量： 25 ,核心点数量： 25 ,非核心点数量： 0 ,噪音点数量： 31
# xq_code： BUSINESS_COMMUNITY-141450072548 112.1715 112.1715 32.054012 32.054012
# 当前计算第 124 个小区
# xq_code： BUSINESS_COMMUNITY-141450072553 :全部数据点： 127 个：可用数据点： 80 个：异常数据点: 47 个
# xq_code： BUSINESS_COMMUNITY-141450072553 ,计算点数量： 80 ,成员点数量： 67 ,核心点数量： 67 ,非核心点数量： 0 ,噪音点数量： 13
# xq_code： BUSINESS_COMMUNITY-141450072553 112.18191499999999 112.18173 32.0471 32.04688
# 当前计算第 125 个小区
# xq_code： BUSINESS_COMMUNITY-141450072558 :全部数据点： 93 个：可用数据点： 74 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450072558 ,计算点数量： 74 ,成员点数量： 48 ,核心点数量： 48 ,非核心点数量： 0 ,噪音点数量： 26
# xq_code： BUSINESS_COMMUNITY-141450072558 112.15378 112.15331 32.04889 32.04833
# 当前计算第 126 个小区
# xq_code： BUSINESS_COMMUNITY-141450072563 :全部数据点： 125 个：可用数据点： 105 个：异常数据点: 20 个
# 当前计算第 127 个小区
# xq_code： BUSINESS_COMMUNITY-141450072637 :全部数据点： 58 个：可用数据点： 45 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450072637 ,计算点数量： 45 ,成员点数量： 25 ,核心点数量： 25 ,非核心点数量： 0 ,噪音点数量： 20
# xq_code： BUSINESS_COMMUNITY-141450072637 112.24785 112.24732 31.70707 31.70632
# 当前计算第 128 个小区
# xq_code： BUSINESS_COMMUNITY-141450072681 :全部数据点： 90 个：可用数据点： 66 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450072681 ,计算点数量： 66 ,成员点数量： 27 ,核心点数量： 27 ,非核心点数量： 0 ,噪音点数量： 39
# xq_code： BUSINESS_COMMUNITY-141450072681 112.18721000000001 112.18721000000001 32.04616 32.04616
# 当前计算第 129 个小区
# xq_code： BUSINESS_COMMUNITY-141450072708 :全部数据点： 86 个：可用数据点： 67 个：异常数据点: 19 个
# 当前计算第 130 个小区
# xq_code： BUSINESS_COMMUNITY-141450072717 :全部数据点： 62 个：可用数据点： 56 个：异常数据点: 6 个
# 当前计算第 131 个小区
# xq_code： BUSINESS_COMMUNITY-141450072785 :全部数据点： 40 个：可用数据点： 26 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450072785 ,计算点数量： 26 ,成员点数量： 10 ,核心点数量： 10 ,非核心点数量： 0 ,噪音点数量： 16
# xq_code： BUSINESS_COMMUNITY-141450072785 112.15065 112.15065 32.047940000000004 32.047940000000004
# 当前计算第 132 个小区
# xq_code： BUSINESS_COMMUNITY-141450072791 :全部数据点： 37 个：可用数据点： 26 个：异常数据点: 11 个
# 当前计算第 133 个小区
# xq_code： BUSINESS_COMMUNITY-141450072862 :全部数据点： 67 个：可用数据点： 54 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450072862 ,计算点数量： 54 ,成员点数量： 31 ,核心点数量： 31 ,非核心点数量： 0 ,噪音点数量： 23
# xq_code： BUSINESS_COMMUNITY-141450072862 111.67858999999999 111.67855 32.36161 32.361340000000006
# 当前计算第 134 个小区
# xq_code： BUSINESS_COMMUNITY-141450072901 :全部数据点： 82 个：可用数据点： 72 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-141450072901 ,计算点数量： 72 ,成员点数量： 45 ,核心点数量： 45 ,非核心点数量： 0 ,噪音点数量： 27
# xq_code： BUSINESS_COMMUNITY-141450072901 112.15733999999999 112.15685 32.057941 32.056564
# 当前计算第 135 个小区
# xq_code： BUSINESS_COMMUNITY-141450072985 :全部数据点： 27 个：可用数据点： 23 个：异常数据点: 4 个
# xq_code： BUSINESS_COMMUNITY-141450072985 ,计算点数量： 23 ,成员点数量： 9 ,核心点数量： 9 ,非核心点数量： 0 ,噪音点数量： 14
# xq_code： BUSINESS_COMMUNITY-141450072985 112.25026000000001 112.25026000000001 31.70913 31.70913
# 当前计算第 136 个小区
# xq_code： BUSINESS_COMMUNITY-141450073011 :全部数据点： 109 个：可用数据点： 84 个：异常数据点: 25 个
# 当前计算第 137 个小区
# xq_code： BUSINESS_COMMUNITY-141450073048 :全部数据点： 60 个：可用数据点： 40 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450073048 ,计算点数量： 40 ,成员点数量： 29 ,核心点数量： 29 ,非核心点数量： 0 ,噪音点数量： 11
# xq_code： BUSINESS_COMMUNITY-141450073048 111.64151000000001 111.64151000000001 32.258765999999994 32.258765999999994
# 当前计算第 138 个小区
# xq_code： BUSINESS_COMMUNITY-141450073067 :全部数据点： 99 个：可用数据点： 72 个：异常数据点: 27 个
# 当前计算第 139 个小区
# xq_code： BUSINESS_COMMUNITY-141450073069 :全部数据点： 75 个：可用数据点： 46 个：异常数据点: 29 个
# 当前计算第 140 个小区
# xq_code： BUSINESS_COMMUNITY-141450073075 :全部数据点： 228 个：可用数据点： 159 个：异常数据点: 69 个
# 当前计算第 141 个小区
# xq_code： BUSINESS_COMMUNITY-141450073125 :全部数据点： 144 个：可用数据点： 97 个：异常数据点: 47 个
# 当前计算第 142 个小区
# xq_code： BUSINESS_COMMUNITY-141450073161 :全部数据点： 83 个：可用数据点： 65 个：异常数据点: 18 个
# 当前计算第 143 个小区
# xq_code： BUSINESS_COMMUNITY-141450073171 :全部数据点： 52 个：可用数据点： 37 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450073171 ,计算点数量： 37 ,成员点数量： 28 ,核心点数量： 28 ,非核心点数量： 0 ,噪音点数量： 9
# xq_code： BUSINESS_COMMUNITY-141450073171 112.12471000000001 112.12471000000001 32.04221 32.04221
# 当前计算第 144 个小区
# xq_code： BUSINESS_COMMUNITY-141450073173 :全部数据点： 77 个：可用数据点： 54 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450073173 ,计算点数量： 54 ,成员点数量： 31 ,核心点数量： 31 ,非核心点数量： 0 ,噪音点数量： 23
# xq_code： BUSINESS_COMMUNITY-141450073173 112.11383000000001 112.11322 32.049490000000006 32.04907
# 当前计算第 145 个小区
# xq_code： BUSINESS_COMMUNITY-141450073176 :全部数据点： 47 个：可用数据点： 40 个：异常数据点: 7 个
# 当前计算第 146 个小区
# xq_code： BUSINESS_COMMUNITY-141450073329 :全部数据点： 110 个：可用数据点： 91 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450073329 ,计算点数量： 91 ,成员点数量： 54 ,核心点数量： 54 ,非核心点数量： 0 ,噪音点数量： 37
# xq_code： BUSINESS_COMMUNITY-141450073329 112.25532 112.25527 30.326378000000002 30.326084
# 当前计算第 147 个小区
# xq_code： BUSINESS_COMMUNITY-141450073425 :全部数据点： 47 个：可用数据点： 39 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450073425 ,计算点数量： 39 ,成员点数量： 19 ,核心点数量： 17 ,非核心点数量： 2 ,噪音点数量： 20
# xq_code： BUSINESS_COMMUNITY-141450073425 112.26431000000001 112.26333600000001 30.311039 30.31033
# 当前计算第 148 个小区
# xq_code： BUSINESS_COMMUNITY-141450073607 :全部数据点： 121 个：可用数据点： 106 个：异常数据点: 15 个
# 当前计算第 149 个小区
# xq_code： BUSINESS_COMMUNITY-141450073747 :全部数据点： 384 个：可用数据点： 293 个：异常数据点: 91 个
# 当前计算第 150 个小区
# xq_code： BUSINESS_COMMUNITY-141450075117 :全部数据点： 89 个：可用数据点： 64 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450075117 ,计算点数量： 64 ,成员点数量： 35 ,核心点数量： 35 ,非核心点数量： 0 ,噪音点数量： 29
# xq_code： BUSINESS_COMMUNITY-141450075117 112.43165 112.43155 30.041490000000003 30.041359999999997
# 当前计算第 151 个小区
# xq_code： BUSINESS_COMMUNITY-141450076178 :全部数据点： 147 个：可用数据点： 97 个：异常数据点: 50 个
# xq_code： BUSINESS_COMMUNITY-141450076178 ,计算点数量： 97 ,成员点数量： 40 ,核心点数量： 40 ,非核心点数量： 0 ,噪音点数量： 57
# xq_code： BUSINESS_COMMUNITY-141450076178 114.86146000000001 114.86146000000001 30.6334799999999 30.6334799999999
# 当前计算第 152 个小区
# xq_code： BUSINESS_COMMUNITY-141450076327 :全部数据点： 55 个：可用数据点： 43 个：异常数据点: 12 个
# 当前计算第 153 个小区
# xq_code： BUSINESS_COMMUNITY-141450076331 :全部数据点： 70 个：可用数据点： 49 个：异常数据点: 21 个
# 当前计算第 154 个小区
# xq_code： BUSINESS_COMMUNITY-141450076486 :全部数据点： 71 个：可用数据点： 48 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450076486 ,计算点数量： 48 ,成员点数量： 31 ,核心点数量： 31 ,非核心点数量： 0 ,噪音点数量： 17
# xq_code： BUSINESS_COMMUNITY-141450076486 114.91223000000001 114.91223000000001 30.452872999999997 30.452872999999997
# 当前计算第 155 个小区
# xq_code： BUSINESS_COMMUNITY-141450076546 :全部数据点： 63 个：可用数据点： 48 个：异常数据点: 15 个
# 当前计算第 156 个小区
# xq_code： BUSINESS_COMMUNITY-141450076550 :全部数据点： 20 个：可用数据点： 17 个：异常数据点: 3 个
# xq_code： BUSINESS_COMMUNITY-141450076550 ,计算点数量： 17 ,成员点数量： 9 ,核心点数量： 9 ,非核心点数量： 0 ,噪音点数量： 8
# xq_code： BUSINESS_COMMUNITY-141450076550 114.87733500000002 114.87711999999999 30.4341 30.433259999999997
# 当前计算第 157 个小区
# xq_code： BUSINESS_COMMUNITY-141450076603 :全部数据点： 36 个：可用数据点： 30 个：异常数据点: 6 个
# xq_code： BUSINESS_COMMUNITY-141450076603 ,计算点数量： 30 ,成员点数量： 13 ,核心点数量： 13 ,非核心点数量： 0 ,噪音点数量： 17
# xq_code： BUSINESS_COMMUNITY-141450076603 114.874555 114.87454 30.449198 30.449122999999997
# 当前计算第 158 个小区
# xq_code： BUSINESS_COMMUNITY-141450076891 :全部数据点： 57 个：可用数据点： 42 个：异常数据点: 15 个
# 当前计算第 159 个小区
# xq_code： BUSINESS_COMMUNITY-141450076956 :全部数据点： 21 个：可用数据点： 17 个：异常数据点: 4 个
# 当前计算第 160 个小区
# xq_code： BUSINESS_COMMUNITY-141450077018 :全部数据点： 161 个：可用数据点： 129 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450077018 ,计算点数量： 129 ,成员点数量： 62 ,核心点数量： 62 ,非核心点数量： 0 ,噪音点数量： 67
# xq_code： BUSINESS_COMMUNITY-141450077018 111.63524895 111.63420673 31.07241319 31.07150577
# 当前计算第 161 个小区
# xq_code： BUSINESS_COMMUNITY-141450077036 :全部数据点： 47 个：可用数据点： 38 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141450077036 ,计算点数量： 38 ,成员点数量： 17 ,核心点数量： 17 ,非核心点数量： 0 ,噪音点数量： 21
# xq_code： BUSINESS_COMMUNITY-141450077036 111.637542 111.63727919 31.0615706 31.060834000000003
# 当前计算第 162 个小区
# xq_code： BUSINESS_COMMUNITY-141450077044 :全部数据点： 71 个：可用数据点： 53 个：异常数据点: 18 个
# 当前计算第 163 个小区
# xq_code： BUSINESS_COMMUNITY-141450077046 :全部数据点： 50 个：可用数据点： 42 个：异常数据点: 8 个
# 当前计算第 164 个小区
# xq_code： BUSINESS_COMMUNITY-141450077053 :全部数据点： 82 个：可用数据点： 69 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450077053 ,计算点数量： 69 ,成员点数量： 36 ,核心点数量： 32 ,非核心点数量： 4 ,噪音点数量： 33
# xq_code： BUSINESS_COMMUNITY-141450077053 111.63785203 111.636501 31.06247286 31.06085
# 当前计算第 165 个小区
# xq_code： BUSINESS_COMMUNITY-141450077055 :全部数据点： 35 个：可用数据点： 29 个：异常数据点: 6 个
# 当前计算第 166 个小区
# xq_code： BUSINESS_COMMUNITY-141450077070 :全部数据点： 85 个：可用数据点： 59 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-141450077070 ,计算点数量： 59 ,成员点数量： 24 ,核心点数量： 24 ,非核心点数量： 0 ,噪音点数量： 35
# xq_code： BUSINESS_COMMUNITY-141450077070 111.629929 111.629901 31.072769 31.072731
# 当前计算第 167 个小区
# xq_code： BUSINESS_COMMUNITY-141450077108 :全部数据点： 73 个：可用数据点： 57 个：异常数据点: 16 个
# 当前计算第 168 个小区
# xq_code： BUSINESS_COMMUNITY-141450077115 :全部数据点： 136 个：可用数据点： 98 个：异常数据点: 38 个
# 当前计算第 169 个小区
# xq_code： BUSINESS_COMMUNITY-141450077137 :全部数据点： 267 个：可用数据点： 187 个：异常数据点: 80 个
# 当前计算第 170 个小区
# xq_code： BUSINESS_COMMUNITY-141450077141 :全部数据点： 170 个：可用数据点： 109 个：异常数据点: 61 个
# 当前计算第 171 个小区
# xq_code： BUSINESS_COMMUNITY-141450077150 :全部数据点： 139 个：可用数据点： 100 个：异常数据点: 39 个
# 当前计算第 172 个小区
# xq_code： BUSINESS_COMMUNITY-141450077185 :全部数据点： 287 个：可用数据点： 192 个：异常数据点: 95 个
# 当前计算第 173 个小区
# xq_code： BUSINESS_COMMUNITY-141450077195 :全部数据点： 185 个：可用数据点： 140 个：异常数据点: 45 个
# 当前计算第 174 个小区
# xq_code： BUSINESS_COMMUNITY-141450077199 :全部数据点： 52 个：可用数据点： 39 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450077199 ,计算点数量： 39 ,成员点数量： 29 ,核心点数量： 28 ,非核心点数量： 1 ,噪音点数量： 10
# xq_code： BUSINESS_COMMUNITY-141450077199 111.32305 111.32161799999999 30.76948426 30.768394
# 当前计算第 175 个小区
# xq_code： BUSINESS_COMMUNITY-141450077200 :全部数据点： 11 个：可用数据点： 9 个：异常数据点: 2 个
# xq_code： BUSINESS_COMMUNITY-141450077200 ,计算点数量： 9 ,成员点数量： 4 ,核心点数量： 4 ,非核心点数量： 0 ,噪音点数量： 5
# xq_code： BUSINESS_COMMUNITY-141450077200 111.3087 111.30867099999999 30.762285 30.762238
# 当前计算第 176 个小区
# xq_code： BUSINESS_COMMUNITY-141450077254 :全部数据点： 46 个：可用数据点： 0 个：异常数据点: 46 个
# 当前计算第 177 个小区
# xq_code： BUSINESS_COMMUNITY-141450077266 :全部数据点： 182 个：可用数据点： 0 个：异常数据点: 182 个
# 当前计算第 178 个小区
# xq_code： BUSINESS_COMMUNITY-141450077282 :全部数据点： 120 个：可用数据点： 89 个：异常数据点: 31 个
# 当前计算第 179 个小区
# xq_code： BUSINESS_COMMUNITY-141450077283 :全部数据点： 47 个：可用数据点： 41 个：异常数据点: 6 个
# xq_code： BUSINESS_COMMUNITY-141450077283 ,计算点数量： 41 ,成员点数量： 24 ,核心点数量： 24 ,非核心点数量： 0 ,噪音点数量： 17
# xq_code： BUSINESS_COMMUNITY-141450077283 111.77471000000001 111.7747 30.849490000000003 30.849457
# 当前计算第 180 个小区
# xq_code： BUSINESS_COMMUNITY-141450077306 :全部数据点： 81 个：可用数据点： 56 个：异常数据点: 25 个
# 当前计算第 181 个小区
# xq_code： BUSINESS_COMMUNITY-141450077362 :全部数据点： 108 个：可用数据点： 85 个：异常数据点: 23 个
# 当前计算第 182 个小区
# xq_code： BUSINESS_COMMUNITY-141450077372 :全部数据点： 58 个：可用数据点： 37 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450077372 ,计算点数量： 37 ,成员点数量： 21 ,核心点数量： 21 ,非核心点数量： 0 ,噪音点数量： 16
# xq_code： BUSINESS_COMMUNITY-141450077372 111.81166100000002 111.81165 30.82023 30.8202
# 当前计算第 183 个小区
# xq_code： BUSINESS_COMMUNITY-141450077377 :全部数据点： 75 个：可用数据点： 57 个：异常数据点: 18 个
# 当前计算第 184 个小区
# xq_code： BUSINESS_COMMUNITY-141450077389 :全部数据点： 85 个：可用数据点： 31 个：异常数据点: 54 个
# 当前计算第 185 个小区
# xq_code： BUSINESS_COMMUNITY-141450077398 :全部数据点： 86 个：可用数据点： 60 个：异常数据点: 26 个
# 当前计算第 186 个小区
# xq_code： BUSINESS_COMMUNITY-141450077929 :全部数据点： 191 个：可用数据点： 114 个：异常数据点: 77 个
# 当前计算第 187 个小区
# xq_code： BUSINESS_COMMUNITY-141450077930 :全部数据点： 79 个：可用数据点： 61 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450077930 ,计算点数量： 61 ,成员点数量： 25 ,核心点数量： 25 ,非核心点数量： 0 ,噪音点数量： 36
# xq_code： BUSINESS_COMMUNITY-141450077930 111.19198600000001 111.19198600000001 30.46929 30.46929
# 当前计算第 188 个小区
# xq_code： BUSINESS_COMMUNITY-141450077932 :全部数据点： 32 个：可用数据点： 27 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450077932 ,计算点数量： 27 ,成员点数量： 14 ,核心点数量： 14 ,非核心点数量： 0 ,噪音点数量： 13
# xq_code： BUSINESS_COMMUNITY-141450077932 111.19099399999999 111.19099399999999 30.471159999999998 30.471159999999998
# 当前计算第 189 个小区
# xq_code： BUSINESS_COMMUNITY-141450077936 :全部数据点： 78 个：可用数据点： 49 个：异常数据点: 29 个
# xq_code： BUSINESS_COMMUNITY-141450077936 ,计算点数量： 49 ,成员点数量： 20 ,核心点数量： 1 ,非核心点数量： 19 ,噪音点数量： 29
# xq_code： BUSINESS_COMMUNITY-141450077936 111.19314550000001 111.19198600000001 30.47024479 30.46929
# 当前计算第 190 个小区
# xq_code： BUSINESS_COMMUNITY-141450077940 :全部数据点： 76 个：可用数据点： 62 个：异常数据点: 14 个
# 当前计算第 191 个小区
# xq_code： BUSINESS_COMMUNITY-141450077946 :全部数据点： 11 个：可用数据点： 7 个：异常数据点: 4 个
# xq_code： BUSINESS_COMMUNITY-141450077946 ,计算点数量： 7 ,成员点数量： 3 ,核心点数量： 3 ,非核心点数量： 0 ,噪音点数量： 4
# xq_code： BUSINESS_COMMUNITY-141450077946 111.18886 111.18886 30.46783 30.46783
# 当前计算第 192 个小区
# xq_code： BUSINESS_COMMUNITY-141450077965 :全部数据点： 124 个：可用数据点： 94 个：异常数据点: 30 个
# 当前计算第 193 个小区
# xq_code： BUSINESS_COMMUNITY-141450077969 :全部数据点： 47 个：可用数据点： 34 个：异常数据点: 13 个
# 当前计算第 194 个小区
# xq_code： BUSINESS_COMMUNITY-141450078103 :全部数据点： 17 个：可用数据点： 15 个：异常数据点: 2 个
# xq_code： BUSINESS_COMMUNITY-141450078103 ,计算点数量： 15 ,成员点数量： 8 ,核心点数量： 8 ,非核心点数量： 0 ,噪音点数量： 7
# xq_code： BUSINESS_COMMUNITY-141450078103 111.18794 111.1879 30.473709999999997 30.47355
# 当前计算第 195 个小区
# xq_code： BUSINESS_COMMUNITY-141450078107 :全部数据点： 32 个：可用数据点： 25 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450078107 ,计算点数量： 25 ,成员点数量： 12 ,核心点数量： 12 ,非核心点数量： 0 ,噪音点数量： 13
# xq_code： BUSINESS_COMMUNITY-141450078107 111.18794 111.1879 30.473709999999997 30.47355
# 当前计算第 196 个小区
# xq_code： BUSINESS_COMMUNITY-141450078139 :全部数据点： 114 个：可用数据点： 70 个：异常数据点: 44 个
# 当前计算第 197 个小区
# xq_code： BUSINESS_COMMUNITY-141450855210 :全部数据点： 39 个：可用数据点： 27 个：异常数据点: 12 个
# 当前计算第 198 个小区
# xq_code： BUSINESS_COMMUNITY-141450855289 :全部数据点： 237 个：可用数据点： 179 个：异常数据点: 58 个
# 当前计算第 199 个小区
# xq_code： BUSINESS_COMMUNITY-141450855292 :全部数据点： 129 个：可用数据点： 97 个：异常数据点: 32 个
# 当前计算第 200 个小区
# xq_code： BUSINESS_COMMUNITY-141450855316 :全部数据点： 105 个：可用数据点： 72 个：异常数据点: 33 个
# xq_code： BUSINESS_COMMUNITY-141450855316 ,计算点数量： 72 ,成员点数量： 52 ,核心点数量： 52 ,非核心点数量： 0 ,噪音点数量： 20
# xq_code： BUSINESS_COMMUNITY-141450855316 115.632058 115.63202 30.762929999999997 30.762815999999997
# 当前计算第 201 个小区
# xq_code： BUSINESS_COMMUNITY-141450855331 :全部数据点： 108 个：可用数据点： 73 个：异常数据点: 35 个
# 当前计算第 202 个小区
# xq_code： BUSINESS_COMMUNITY-141450856978 :全部数据点： 61 个：可用数据点： 43 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450856978 ,计算点数量： 43 ,成员点数量： 23 ,核心点数量： 23 ,非核心点数量： 0 ,噪音点数量： 20
# xq_code： BUSINESS_COMMUNITY-141450856978 111.29697 111.29697 30.71762 30.71762
# 当前计算第 203 个小区
# xq_code： BUSINESS_COMMUNITY-141450856979 :全部数据点： 17 个：可用数据点： 14 个：异常数据点: 3 个
# 当前计算第 204 个小区
# xq_code： BUSINESS_COMMUNITY-141450856990 :全部数据点： 88 个：可用数据点： 58 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-141450856990 ,计算点数量： 58 ,成员点数量： 26 ,核心点数量： 25 ,非核心点数量： 1 ,噪音点数量： 32
# xq_code： BUSINESS_COMMUNITY-141450856990 111.279881 111.27889957 30.73078519 30.730290000000004
# 当前计算第 205 个小区
# xq_code： BUSINESS_COMMUNITY-141450857006 :全部数据点： 145 个：可用数据点： 102 个：异常数据点: 43 个
# 当前计算第 206 个小区
# xq_code： BUSINESS_COMMUNITY-141450857009 :全部数据点： 58 个：可用数据点： 42 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450857009 ,计算点数量： 42 ,成员点数量： 18 ,核心点数量： 18 ,非核心点数量： 0 ,噪音点数量： 24
# xq_code： BUSINESS_COMMUNITY-141450857009 111.2908 111.29026999999999 30.718020000000003 30.717246999999997
# 当前计算第 207 个小区
# xq_code： BUSINESS_COMMUNITY-141450857023 :全部数据点： 38 个：可用数据点： 28 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-141450857023 ,计算点数量： 28 ,成员点数量： 12 ,核心点数量： 11 ,非核心点数量： 1 ,噪音点数量： 16
# xq_code： BUSINESS_COMMUNITY-141450857023 111.29311787 111.291956 30.700329999999997 30.699727000000003
# 当前计算第 208 个小区
# xq_code： BUSINESS_COMMUNITY-141450857072 :全部数据点： 91 个：可用数据点： 68 个：异常数据点: 23 个
# 当前计算第 209 个小区
# xq_code： BUSINESS_COMMUNITY-141450857097 :全部数据点： 107 个：可用数据点： 91 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450857097 ,计算点数量： 91 ,成员点数量： 43 ,核心点数量： 43 ,非核心点数量： 0 ,噪音点数量： 48
# xq_code： BUSINESS_COMMUNITY-141450857097 111.294671 111.294671 30.69701 30.69701
# 当前计算第 210 个小区
# xq_code： BUSINESS_COMMUNITY-141450857110 :全部数据点： 35 个：可用数据点： 27 个：异常数据点: 8 个
# 当前计算第 211 个小区
# xq_code： BUSINESS_COMMUNITY-141450857130 :全部数据点： 121 个：可用数据点： 82 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-141450857130 ,计算点数量： 82 ,成员点数量： 51 ,核心点数量： 51 ,非核心点数量： 0 ,噪音点数量： 31
# xq_code： BUSINESS_COMMUNITY-141450857130 111.27547 111.27546446 30.67985438 30.67983
# 当前计算第 212 个小区
# xq_code： BUSINESS_COMMUNITY-141450857152 :全部数据点： 36 个：可用数据点： 26 个：异常数据点: 10 个
# 当前计算第 213 个小区
# xq_code： BUSINESS_COMMUNITY-141450857160 :全部数据点： 90 个：可用数据点： 61 个：异常数据点: 29 个
# 当前计算第 214 个小区
# xq_code： BUSINESS_COMMUNITY-141450857186 :全部数据点： 95 个：可用数据点： 73 个：异常数据点: 22 个
# 当前计算第 215 个小区
# xq_code： BUSINESS_COMMUNITY-141450857215 :全部数据点： 41 个：可用数据点： 30 个：异常数据点: 11 个
# 当前计算第 216 个小区
# xq_code： BUSINESS_COMMUNITY-141450857343 :全部数据点： 100 个：可用数据点： 81 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450857343 ,计算点数量： 81 ,成员点数量： 32 ,核心点数量： 32 ,非核心点数量： 0 ,噪音点数量： 49
# xq_code： BUSINESS_COMMUNITY-141450857343 111.429221 111.429184 30.542828000000004 30.542271000000003
# 当前计算第 217 个小区
# xq_code： BUSINESS_COMMUNITY-141450857344 :全部数据点： 261 个：可用数据点： 198 个：异常数据点: 63 个
# 当前计算第 218 个小区
# xq_code： BUSINESS_COMMUNITY-141450857379 :全部数据点： 454 个：可用数据点： 334 个：异常数据点: 120 个
# xq_code： BUSINESS_COMMUNITY-141450857379 ,计算点数量： 334 ,成员点数量： 176 ,核心点数量： 176 ,非核心点数量： 0 ,噪音点数量： 158
# xq_code： BUSINESS_COMMUNITY-141450857379 111.73046000000001 111.72896505 30.43397084 30.433413
# 当前计算第 219 个小区
# xq_code： BUSINESS_COMMUNITY-141450857390 :全部数据点： 53 个：可用数据点： 48 个：异常数据点: 5 个
# 当前计算第 220 个小区
# xq_code： BUSINESS_COMMUNITY-141450857423 :全部数据点： 59 个：可用数据点： 47 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450857423 ,计算点数量： 47 ,成员点数量： 21 ,核心点数量： 20 ,非核心点数量： 1 ,噪音点数量： 26
# xq_code： BUSINESS_COMMUNITY-141450857423 111.76121741 111.76088 30.431301 30.43017728
# 当前计算第 221 个小区
# xq_code： BUSINESS_COMMUNITY-141450857462 :全部数据点： 58 个：可用数据点： 37 个：异常数据点: 21 个
# 当前计算第 222 个小区
# xq_code： BUSINESS_COMMUNITY-141450857484 :全部数据点： 117 个：可用数据点： 88 个：异常数据点: 29 个
# 当前计算第 223 个小区
# xq_code： BUSINESS_COMMUNITY-141450857485 :全部数据点： 83 个：可用数据点： 61 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450857485 ,计算点数量： 61 ,成员点数量： 24 ,核心点数量： 24 ,非核心点数量： 0 ,噪音点数量： 37
# xq_code： BUSINESS_COMMUNITY-141450857485 111.34418500000001 111.3433 30.647470000000002 30.647194
# 当前计算第 224 个小区
# xq_code： BUSINESS_COMMUNITY-141450857489 :全部数据点： 83 个：可用数据点： 61 个：异常数据点: 22 个
# 当前计算第 225 个小区
# xq_code： BUSINESS_COMMUNITY-141450857493 :全部数据点： 286 个：可用数据点： 220 个：异常数据点: 66 个
# 当前计算第 226 个小区
# xq_code： BUSINESS_COMMUNITY-141450857503 :全部数据点： 69 个：可用数据点： 52 个：异常数据点: 17 个
# 当前计算第 227 个小区
# xq_code： BUSINESS_COMMUNITY-141450857550 :全部数据点： 25 个：可用数据点： 20 个：异常数据点: 5 个
# 当前计算第 228 个小区
# xq_code： BUSINESS_COMMUNITY-141450857585 :全部数据点： 186 个：可用数据点： 137 个：异常数据点: 49 个
# xq_code： BUSINESS_COMMUNITY-141450857585 ,计算点数量： 137 ,成员点数量： 80 ,核心点数量： 80 ,非核心点数量： 0 ,噪音点数量： 57
# xq_code： BUSINESS_COMMUNITY-141450857585 110.96628999999999 110.96627714 30.83255004 30.83254
# 当前计算第 229 个小区
# xq_code： BUSINESS_COMMUNITY-141450857591 :全部数据点： 60 个：可用数据点： 43 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450857591 ,计算点数量： 43 ,成员点数量： 18 ,核心点数量： 18 ,非核心点数量： 0 ,噪音点数量： 25
# xq_code： BUSINESS_COMMUNITY-141450857591 111.768845 111.768845 30.430918 30.430918
# 当前计算第 230 个小区
# xq_code： BUSINESS_COMMUNITY-141450857607 :全部数据点： 7 个：可用数据点： 0 个：异常数据点: 7 个
# 当前计算第 231 个小区
# xq_code： BUSINESS_COMMUNITY-141450857635 :全部数据点： 129 个：可用数据点： 96 个：异常数据点: 33 个
# 当前计算第 232 个小区
# xq_code： BUSINESS_COMMUNITY-141450857639 :全部数据点： 150 个：可用数据点： 108 个：异常数据点: 42 个
# xq_code： BUSINESS_COMMUNITY-141450857639 ,计算点数量： 108 ,成员点数量： 51 ,核心点数量： 51 ,非核心点数量： 0 ,噪音点数量： 57
# xq_code： BUSINESS_COMMUNITY-141450857639 111.312614 111.312614 30.703251 30.703251
# 当前计算第 233 个小区
# xq_code： BUSINESS_COMMUNITY-141450857645 :全部数据点： 101 个：可用数据点： 70 个：异常数据点: 31 个
# xq_code： BUSINESS_COMMUNITY-141450857645 ,计算点数量： 70 ,成员点数量： 32 ,核心点数量： 32 ,非核心点数量： 0 ,噪音点数量： 38
# xq_code： BUSINESS_COMMUNITY-141450857645 111.30771999999999 111.30771999999999 30.702659999999998 30.702659999999998
# 当前计算第 234 个小区
# xq_code： BUSINESS_COMMUNITY-141450857647 :全部数据点： 121 个：可用数据点： 87 个：异常数据点: 34 个
# xq_code： BUSINESS_COMMUNITY-141450857647 ,计算点数量： 87 ,成员点数量： 42 ,核心点数量： 42 ,非核心点数量： 0 ,噪音点数量： 45
# xq_code： BUSINESS_COMMUNITY-141450857647 111.42809299999999 111.42799 30.53805 30.537751
# 当前计算第 235 个小区
# xq_code： BUSINESS_COMMUNITY-141450857690 :全部数据点： 64 个：可用数据点： 43 个：异常数据点: 21 个
# 当前计算第 236 个小区
# xq_code： BUSINESS_COMMUNITY-141450857694 :全部数据点： 46 个：可用数据点： 34 个：异常数据点: 12 个
# 当前计算第 237 个小区
# xq_code： BUSINESS_COMMUNITY-141450857712 :全部数据点： 33 个：可用数据点： 23 个：异常数据点: 10 个
# 当前计算第 238 个小区
# xq_code： BUSINESS_COMMUNITY-141450857728 :全部数据点： 85 个：可用数据点： 49 个：异常数据点: 36 个
# xq_code： BUSINESS_COMMUNITY-141450857728 ,计算点数量： 49 ,成员点数量： 21 ,核心点数量： 21 ,非核心点数量： 0 ,噪音点数量： 28
# xq_code： BUSINESS_COMMUNITY-141450857728 114.34511599999999 114.34503500000001 29.83255 29.832501
# 当前计算第 239 个小区
# xq_code： BUSINESS_COMMUNITY-141450857740 :全部数据点： 61 个：可用数据点： 42 个：异常数据点: 19 个
# 当前计算第 240 个小区
# xq_code： BUSINESS_COMMUNITY-141450857841 :全部数据点： 201 个：可用数据点： 148 个：异常数据点: 53 个
# 当前计算第 241 个小区
# xq_code： BUSINESS_COMMUNITY-141450857905 :全部数据点： 62 个：可用数据点： 41 个：异常数据点: 21 个
# 当前计算第 242 个小区
# xq_code： BUSINESS_COMMUNITY-141450857911 :全部数据点： 68 个：可用数据点： 50 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450857911 ,计算点数量： 50 ,成员点数量： 26 ,核心点数量： 26 ,非核心点数量： 0 ,噪音点数量： 24
# xq_code： BUSINESS_COMMUNITY-141450857911 114.30398999999998 114.30398999999998 29.87684 29.87684
# 当前计算第 243 个小区
# xq_code： BUSINESS_COMMUNITY-141450857999 :全部数据点： 40 个：可用数据点： 29 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450857999 ,计算点数量： 29 ,成员点数量： 13 ,核心点数量： 13 ,非核心点数量： 0 ,噪音点数量： 16
# xq_code： BUSINESS_COMMUNITY-141450857999 114.34087 114.34087 29.856759999999998 29.856759999999998
# 当前计算第 244 个小区
# xq_code： BUSINESS_COMMUNITY-141450858004 :全部数据点： 78 个：可用数据点： 62 个：异常数据点: 16 个
# 当前计算第 245 个小区
# xq_code： BUSINESS_COMMUNITY-141450858032 :全部数据点： 66 个：可用数据点： 55 个：异常数据点: 11 个
# 当前计算第 246 个小区
# xq_code： BUSINESS_COMMUNITY-141450858074 :全部数据点： 162 个：可用数据点： 117 个：异常数据点: 45 个
# 当前计算第 247 个小区
# xq_code： BUSINESS_COMMUNITY-141450858354 :全部数据点： 669 个：可用数据点： 497 个：异常数据点: 172 个
# 当前计算第 248 个小区
# xq_code： BUSINESS_COMMUNITY-141450858489 :全部数据点： 128 个：可用数据点： 97 个：异常数据点: 31 个
# xq_code： BUSINESS_COMMUNITY-141450858489 ,计算点数量： 97 ,成员点数量： 46 ,核心点数量： 46 ,非核心点数量： 0 ,噪音点数量： 51
# xq_code： BUSINESS_COMMUNITY-141450858489 111.73990928 111.7390215 30.42940064 30.42804891
# 当前计算第 249 个小区
# xq_code： BUSINESS_COMMUNITY-141450858497 :全部数据点： 75 个：可用数据点： 44 个：异常数据点: 31 个
# 当前计算第 250 个小区
# xq_code： BUSINESS_COMMUNITY-141450858501 :全部数据点： 87 个：可用数据点： 50 个：异常数据点: 37 个
# 当前计算第 251 个小区
# xq_code： BUSINESS_COMMUNITY-141450858539 :全部数据点： 76 个：可用数据点： 65 个：异常数据点: 11 个
# 当前计算第 252 个小区
# xq_code： BUSINESS_COMMUNITY-141450858540 :全部数据点： 64 个：可用数据点： 43 个：异常数据点: 21 个
# 当前计算第 253 个小区
# xq_code： BUSINESS_COMMUNITY-141450858543 :全部数据点： 102 个：可用数据点： 85 个：异常数据点: 17 个
# 当前计算第 254 个小区
# xq_code： BUSINESS_COMMUNITY-141450858561 :全部数据点： 91 个：可用数据点： 59 个：异常数据点: 32 个
# 当前计算第 255 个小区
# xq_code： BUSINESS_COMMUNITY-141450858606 :全部数据点： 32 个：可用数据点： 20 个：异常数据点: 12 个
# 当前计算第 256 个小区
# xq_code： BUSINESS_COMMUNITY-141450858608 :全部数据点： 25 个：可用数据点： 12 个：异常数据点: 13 个
# 当前计算第 257 个小区
# xq_code： BUSINESS_COMMUNITY-141450858629 :全部数据点： 119 个：可用数据点： 95 个：异常数据点: 24 个
# 当前计算第 258 个小区
# xq_code： BUSINESS_COMMUNITY-141450858630 :全部数据点： 36 个：可用数据点： 29 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450858630 ,计算点数量： 29 ,成员点数量： 12 ,核心点数量： 12 ,非核心点数量： 0 ,噪音点数量： 17
# xq_code： BUSINESS_COMMUNITY-141450858630 113.43621 113.4359 30.371335 30.371028999999997
# 当前计算第 259 个小区
# xq_code： BUSINESS_COMMUNITY-141450858632 :全部数据点： 68 个：可用数据点： 55 个：异常数据点: 13 个
# 当前计算第 260 个小区
# xq_code： BUSINESS_COMMUNITY-141450858636 :全部数据点： 70 个：可用数据点： 59 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450858636 ,计算点数量： 59 ,成员点数量： 25 ,核心点数量： 25 ,非核心点数量： 0 ,噪音点数量： 34
# xq_code： BUSINESS_COMMUNITY-141450858636 113.45768999999999 113.45768999999999 30.36243 30.36243
# 当前计算第 261 个小区
# xq_code： BUSINESS_COMMUNITY-141450858641 :全部数据点： 78 个：可用数据点： 60 个：异常数据点: 18 个
# 当前计算第 262 个小区
# xq_code： BUSINESS_COMMUNITY-141450858643 :全部数据点： 221 个：可用数据点： 175 个：异常数据点: 46 个
# 当前计算第 263 个小区
# xq_code： BUSINESS_COMMUNITY-141450858679 :全部数据点： 110 个：可用数据点： 88 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450858679 ,计算点数量： 88 ,成员点数量： 49 ,核心点数量： 49 ,非核心点数量： 0 ,噪音点数量： 39
# xq_code： BUSINESS_COMMUNITY-141450858679 113.43061999999999 113.43053 30.37466 30.37462
# 当前计算第 264 个小区
# xq_code： BUSINESS_COMMUNITY-141450858681 :全部数据点： 72 个：可用数据点： 53 个：异常数据点: 19 个
# 当前计算第 265 个小区
# xq_code： BUSINESS_COMMUNITY-141450858685 :全部数据点： 94 个：可用数据点： 74 个：异常数据点: 20 个
# 当前计算第 266 个小区
# xq_code： BUSINESS_COMMUNITY-141450858699 :全部数据点： 138 个：可用数据点： 95 个：异常数据点: 43 个
# 当前计算第 267 个小区
# xq_code： BUSINESS_COMMUNITY-141450858762 :全部数据点： 135 个：可用数据点： 95 个：异常数据点: 40 个
# 当前计算第 268 个小区
# xq_code： BUSINESS_COMMUNITY-141450858764 :全部数据点： 44 个：可用数据点： 26 个：异常数据点: 18 个
# 当前计算第 269 个小区
# xq_code： BUSINESS_COMMUNITY-141450858822 :全部数据点： 91 个：可用数据点： 76 个：异常数据点: 15 个
# 当前计算第 270 个小区
# xq_code： BUSINESS_COMMUNITY-141450858880 :全部数据点： 113 个：可用数据点： 73 个：异常数据点: 40 个
# xq_code： BUSINESS_COMMUNITY-141450858880 ,计算点数量： 73 ,成员点数量： 34 ,核心点数量： 1 ,非核心点数量： 33 ,噪音点数量： 39
# xq_code： BUSINESS_COMMUNITY-141450858880 111.31482199999999 111.314171 30.67268149 30.671511
# 当前计算第 271 个小区
# xq_code： BUSINESS_COMMUNITY-141450858881 :全部数据点： 61 个：可用数据点： 37 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450858881 ,计算点数量： 37 ,成员点数量： 20 ,核心点数量： 20 ,非核心点数量： 0 ,噪音点数量： 17
# xq_code： BUSINESS_COMMUNITY-141450858881 111.34217 111.34170174 30.64865582 30.648138
# 当前计算第 272 个小区
# xq_code： BUSINESS_COMMUNITY-141450858964 :全部数据点： 155 个：可用数据点： 109 个：异常数据点: 46 个
# 当前计算第 273 个小区
# xq_code： BUSINESS_COMMUNITY-141450858984 :全部数据点： 42 个：可用数据点： 34 个：异常数据点: 8 个
# 当前计算第 274 个小区
# xq_code： BUSINESS_COMMUNITY-141450859000 :全部数据点： 221 个：可用数据点： 171 个：异常数据点: 50 个
# xq_code： BUSINESS_COMMUNITY-141450859000 ,计算点数量： 171 ,成员点数量： 99 ,核心点数量： 98 ,非核心点数量： 1 ,噪音点数量： 72
# xq_code： BUSINESS_COMMUNITY-141450859000 113.159874 113.1593264 30.66981821 30.668509000000004
# 当前计算第 275 个小区
# xq_code： BUSINESS_COMMUNITY-141450859039 :全部数据点： 41 个：可用数据点： 36 个：异常数据点: 5 个
# ...
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167ca7794165c68 ,计算点数量： 26 ,成员点数量： 17 ,核心点数量： 16 ,非核心点数量： 1 ,噪音点数量： 9
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167ca7794165c68 114.16494288 114.16322 30.646472999999997 30.64600818
# 当前计算第 2411 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167cabb8a555d80 :全部数据点： 17 个：可用数据点： 14 个：异常数据点: 3 个
# 当前计算第 2412 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167cff0a5076170 :全部数据点： 29 个：可用数据点： 18 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167cff0a5076170 ,计算点数量： 18 ,成员点数量： 10 ,核心点数量： 10 ,非核心点数量： 0 ,噪音点数量： 8
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167cff0a5076170 114.62753300000001 114.62752999999901 31.268960999999997 31.268959999999996
# 当前计算第 2413 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167df25946066d8 :全部数据点： 30 个：可用数据点： 21 个：异常数据点: 9 个
# 当前计算第 2414 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e2f8f4936770 :全部数据点： 62 个：可用数据点： 47 个：异常数据点: 15 个
# 当前计算第 2415 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e3f839c668f8 :全部数据点： 24 个：可用数据点： 12 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e3f839c668f8 ,计算点数量： 12 ,成员点数量： 8 ,核心点数量： 8 ,非核心点数量： 0 ,噪音点数量： 4
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e3f839c668f8 110.31816 110.31816 30.58036 30.58036
# 当前计算第 2416 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e5f0e44a6ad0 :全部数据点： 52 个：可用数据点： 35 个：异常数据点: 17 个
# 当前计算第 2417 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e5f7912e6ad8 :全部数据点： 31 个：可用数据点： 25 个：异常数据点: 6 个
# 当前计算第 2418 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e91d43926ca0 :全部数据点： 138 个：可用数据点： 98 个：异常数据点: 40 个
# 当前计算第 2419 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167eea939987008 :全部数据点： 63 个：可用数据点： 58 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167eea939987008 ,计算点数量： 58 ,成员点数量： 29 ,核心点数量： 29 ,非核心点数量： 0 ,噪音点数量： 29
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167eea939987008 108.96117 108.96117 30.277379999999997 30.277379999999997
# 当前计算第 2420 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167f7d221fa7578 :全部数据点： 26 个：可用数据点： 18 个：异常数据点: 8 个
# 当前计算第 2421 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba5401596753e676080f :全部数据点： 135 个：可用数据点： 107 个：异常数据点: 28 个
# 当前计算第 2422 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba54015971d4144274e3 :全部数据点： 84 个：可用数据点： 61 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba54015971d4144274e3 ,计算点数量： 61 ,成员点数量： 24 ,核心点数量： 24 ,非核心点数量： 0 ,噪音点数量： 37
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba54015971d4144274e3 110.78675 110.78675 32.654790000000006 32.654790000000006
# 当前计算第 2423 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba54015971f700c02190 :全部数据点： 24 个：可用数据点： 18 个：异常数据点: 6 个
# 当前计算第 2424 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba54015972ca5f8542ef :全部数据点： 177 个：可用数据点： 143 个：异常数据点: 34 个
# 当前计算第 2425 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159b9fb2fbb2ed4 :全部数据点： 50 个：可用数据点： 33 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159b9fb2fbb2ed4 ,计算点数量： 33 ,成员点数量： 20 ,核心点数量： 20 ,非核心点数量： 0 ,噪音点数量： 13
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159b9fb2fbb2ed4 114.132355 114.13231 31.566332 31.566240000000004
# 当前计算第 2426 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b3641e04 :全部数据点： 70 个：可用数据点： 40 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b3641e04 ,计算点数量： 40 ,成员点数量： 31 ,核心点数量： 31 ,非核心点数量： 0 ,噪音点数量： 9
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b3641e04 115.29998300000001 115.29951000000001 30.921713 30.921033
# 当前计算第 2427 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159c782e3ad31ea :全部数据点： 83 个：可用数据点： 46 个：异常数据点: 37 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159c782e3ad31ea ,计算点数量： 46 ,成员点数量： 21 ,核心点数量： 21 ,非核心点数量： 0 ,噪音点数量： 25
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159c782e3ad31ea 112.75251999999999 112.75251999999999 32.11515 32.11515
# 当前计算第 2428 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159c785297b31ee :全部数据点： 216 个：可用数据点： 128 个：异常数据点: 88 个
# 当前计算第 2429 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159c79a66d5320e :全部数据点： 120 个：可用数据点： 73 个：异常数据点: 47 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159c79a66d5320e ,计算点数量： 73 ,成员点数量： 32 ,核心点数量： 30 ,非核心点数量： 2 ,噪音点数量： 41
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159c79a66d5320e 112.76391000000001 112.763112 32.122057 32.121
# 当前计算第 2430 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a12d2e9990cff :全部数据点： 47 个：可用数据点： 31 个：异常数据点: 16 个
# 当前计算第 2431 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a13089ef52249 :全部数据点： 57 个：可用数据点： 38 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a13089ef52249 ,计算点数量： 38 ,成员点数量： 17 ,核心点数量： 17 ,非核心点数量： 0 ,噪音点数量： 21
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a13089ef52249 112.14796399999999 112.14796399999999 32.054657 32.054657
# 当前计算第 2432 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a1676274d633c :全部数据点： 203 个：可用数据点： 119 个：异常数据点: 84 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a1676274d633c ,计算点数量： 119 ,成员点数量： 67 ,核心点数量： 58 ,非核心点数量： 9 ,噪音点数量： 52
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a1676274d633c 112.14299 112.14246999999999 32.03942 32.03791
# 当前计算第 2433 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a16b07b357e74 :全部数据点： 171 个：可用数据点： 128 个：异常数据点: 43 个
# 当前计算第 2434 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a16b56939029d :全部数据点： 42 个：可用数据点： 24 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a16b56939029d ,计算点数量： 24 ,成员点数量： 10 ,核心点数量： 10 ,非核心点数量： 0 ,噪音点数量： 14
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a16b56939029d 112.15057 112.150449 32.063744 32.063735
# 当前计算第 2435 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a1755b6364c52 :全部数据点： 41 个：可用数据点： 27 个：异常数据点: 14 个
# 当前计算第 2436 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a177dcb045742 :全部数据点： 232 个：可用数据点： 172 个：异常数据点: 60 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a177dcb045742 ,计算点数量： 172 ,成员点数量： 80 ,核心点数量： 80 ,非核心点数量： 0 ,噪音点数量： 92
# xq_code： BUSINESS_COMMUNITY-8a9e74c959ca9f24015a177dcb045742 112.12897 112.128502 32.05281 32.052094
# 当前计算第 2437 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95a40fa1f015a6f447e124ca3 :全部数据点： 10 个：可用数据点： 7 个：异常数据点: 3 个
# 当前计算第 2438 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95b9f12ee015bc7e64aab3419 :全部数据点： 208 个：可用数据点： 152 个：异常数据点: 56 个
# 当前计算第 2439 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95d175599015d345746110674 :全部数据点： 68 个：可用数据点： 55 个：异常数据点: 13 个
# 当前计算第 2440 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95d175599015d4043b04b02e2 :全部数据点： 127 个：可用数据点： 100 个：异常数据点: 27 个
# 当前计算第 2441 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95da059ce015dbbe8fb853095 :全部数据点： 87 个：可用数据点： 76 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95da059ce015dbbe8fb853095 ,计算点数量： 76 ,成员点数量： 47 ,核心点数量： 47 ,非核心点数量： 0 ,噪音点数量： 29
# xq_code： BUSINESS_COMMUNITY-8a9e74c95da059ce015dbbe8fb853095 112.2025 112.20178200000001 30.07218 30.072063
# 当前计算第 2442 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95dd0b034015de02dffc303f9 :全部数据点： 55 个：可用数据点： 45 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95dd0b034015de02dffc303f9 ,计算点数量： 45 ,成员点数量： 23 ,核心点数量： 23 ,非核心点数量： 0 ,噪音点数量： 22
# xq_code： BUSINESS_COMMUNITY-8a9e74c95dd0b034015de02dffc303f9 112.39976999999999 112.39915 29.720209999999998 29.71984
# 当前计算第 2443 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95df678f8015e0777746a6b07 :全部数据点： 55 个：可用数据点： 43 个：异常数据点: 12 个
# 当前计算第 2444 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95df678f8015e07818d0d1389 :全部数据点： 56 个：可用数据点： 43 个：异常数据点: 13 个
# 当前计算第 2445 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95e999f9d015f3416a2d07aa2 :全部数据点： 197 个：可用数据点： 157 个：异常数据点: 40 个
# 当前计算第 2446 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601600aa1cd2c7c71 :全部数据点： 154 个：可用数据点： 131 个：异常数据点: 23 个
# 当前计算第 2447 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc6016043595bd90503 :全部数据点： 55 个：可用数据点： 44 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc6016043595bd90503 ,计算点数量： 44 ,成员点数量： 28 ,核心点数量： 28 ,非核心点数量： 0 ,噪音点数量： 16
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc6016043595bd90503 112.19555 112.19555 30.354309999999998 30.354309999999998
# 当前计算第 2448 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601604438ae4a1789 :全部数据点： 86 个：可用数据点： 47 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601604438ae4a1789 ,计算点数量： 47 ,成员点数量： 28 ,核心点数量： 28 ,非核心点数量： 0 ,噪音点数量： 19
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601604438ae4a1789 112.07253 112.07253 30.323704 30.323704
# 当前计算第 2449 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601607bd8223625a7 :全部数据点： 68 个：可用数据点： 49 个：异常数据点: 19 个
# 当前计算第 2450 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601609c050e350c53 :全部数据点： 133 个：可用数据点： 100 个：异常数据点: 33 个
# 当前计算第 2451 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601609c06cd3e1138 :全部数据点： 105 个：可用数据点： 87 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601609c06cd3e1138 ,计算点数量： 87 ,成员点数量： 43 ,核心点数量： 43 ,非核心点数量： 0 ,噪音点数量： 44
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601609c06cd3e1138 112.15433 112.15433 30.382409999999997 30.382409999999997
# 当前计算第 2452 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601609c215a0b2433 :全部数据点： 148 个：可用数据点： 121 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601609c215a0b2433 ,计算点数量： 121 ,成员点数量： 61 ,核心点数量： 61 ,非核心点数量： 0 ,噪音点数量： 60
# xq_code： BUSINESS_COMMUNITY-8a9e74c95fe85dc601609c215a0b2433 111.759391 111.759308 30.185124 30.185045000000002
# 当前计算第 2453 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c964354c630164a2144ec52ae1 :全部数据点： 127 个：可用数据点： 84 个：异常数据点: 43 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c964354c630164a2144ec52ae1 ,计算点数量： 84 ,成员点数量： 66 ,核心点数量： 66 ,非核心点数量： 0 ,噪音点数量： 18
# xq_code： BUSINESS_COMMUNITY-8a9e74c964354c630164a2144ec52ae1 112.16503 112.16503 32.022890000000004 32.022890000000004
# 当前计算第 2454 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c9653d334b01654222cdba3505 :全部数据点： 94 个：可用数据点： 67 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c9653d334b01654222cdba3505 ,计算点数量： 67 ,成员点数量： 37 ,核心点数量： 37 ,非核心点数量： 0 ,噪音点数量： 30
# xq_code： BUSINESS_COMMUNITY-8a9e74c9653d334b01654222cdba3505 112.137955 112.13781000000002 32.060448 32.06031
# 当前计算第 2455 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c9653d334b0165422519d93514 :全部数据点： 83 个：可用数据点： 56 个：异常数据点: 27 个
# 当前计算第 2456 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c9657b1d1d016589fcead2342d :全部数据点： 154 个：可用数据点： 127 个：异常数据点: 27 个
# 当前计算第 2457 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca56d1cdff0156e3c992667383 :全部数据点： 66 个：可用数据点： 43 个：异常数据点: 23 个
# 当前计算第 2458 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca56e913b70156ea4e78b779a9 :全部数据点： 112 个：可用数据点： 86 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca56e913b70156ea4e78b779a9 ,计算点数量： 86 ,成员点数量： 54 ,核心点数量： 54 ,非核心点数量： 0 ,噪音点数量： 32
# xq_code： BUSINESS_COMMUNITY-8a9e74ca56e913b70156ea4e78b779a9 114.28411000000001 114.28407834 30.40770287 30.40767
# 当前计算第 2459 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca56e913b70156ea52b78d7a3c :全部数据点： 83 个：可用数据点： 42 个：异常数据点: 41 个
# 当前计算第 2460 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca56e913b70157215e0aa505da :全部数据点： 78 个：可用数据点： 53 个：异常数据点: 25 个
# 当前计算第 2461 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca57551f58015755ea160a7e87 :全部数据点： 89 个：可用数据点： 70 个：异常数据点: 19 个
# 当前计算第 2462 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca57b7be950157bbefd2364b0f :全部数据点： 106 个：可用数据点： 72 个：异常数据点: 34 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca57b7be950157bbefd2364b0f ,计算点数量： 72 ,成员点数量： 34 ,核心点数量： 34 ,非核心点数量： 0 ,噪音点数量： 38
# xq_code： BUSINESS_COMMUNITY-8a9e74ca57b7be950157bbefd2364b0f 110.81298000000001 110.81298000000001 32.58852 32.58852
# 当前计算第 2463 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58004d4e01580a8dfe712061 :全部数据点： 89 个：可用数据点： 72 个：异常数据点: 17 个
# 当前计算第 2464 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58004d4e01580a9a38482593 :全部数据点： 289 个：可用数据点： 199 个：异常数据点: 90 个
# 当前计算第 2465 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58450c2b015846f7987a791d :全部数据点： 70 个：可用数据点： 46 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58450c2b015846f7987a791d ,计算点数量： 46 ,成员点数量： 19 ,核心点数量： 19 ,非核心点数量： 0 ,噪音点数量： 27
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58450c2b015846f7987a791d 112.25481 112.254571 31.703940000000003 31.703681
# 当前计算第 2466 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58450c2b01584c14df326074 :全部数据点： 129 个：可用数据点： 84 个：异常数据点: 45 个
# 当前计算第 2467 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158762013950972 :全部数据点： 296 个：可用数据点： 240 个：异常数据点: 56 个
# 当前计算第 2468 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158762767dc159d :全部数据点： 59 个：可用数据点： 43 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158762767dc159d ,计算点数量： 43 ,成员点数量： 17 ,核心点数量： 3 ,非核心点数量： 14 ,噪音点数量： 26
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158762767dc159d 112.24228000000001 112.24094 30.311709999999998 30.311525
# 当前计算第 2469 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58702288015876502d25215b :全部数据点： 123 个：可用数据点： 97 个：异常数据点: 26 个
# 当前计算第 2470 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158b44cf0c22103 :全部数据点： 59 个：可用数据点： 46 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158b44cf0c22103 ,计算点数量： 46 ,成员点数量： 26 ,核心点数量： 25 ,非核心点数量： 1 ,噪音点数量： 20
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158b44cf0c22103 112.13046000000001 112.12895 32.07841 32.07754
# 当前计算第 2471 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158be512864668b :全部数据点： 74 个：可用数据点： 55 个：异常数据点: 19 个
# 当前计算第 2472 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158c34746373a8e :全部数据点： 106 个：可用数据点： 67 个：异常数据点: 39 个
# 当前计算第 2473 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158c8f88d803ebc :全部数据点： 74 个：可用数据点： 53 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158c8f88d803ebc ,计算点数量： 53 ,成员点数量： 24 ,核心点数量： 24 ,非核心点数量： 0 ,噪音点数量： 29
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158c8f88d803ebc 112.14343999999998 112.14316699999999 32.04741 32.046784
# 当前计算第 2474 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158c8fc49563f32 :全部数据点： 71 个：可用数据点： 48 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158c8fc49563f32 ,计算点数量： 48 ,成员点数量： 21 ,核心点数量： 21 ,非核心点数量： 0 ,噪音点数量： 27
# xq_code： BUSINESS_COMMUNITY-8a9e74ca587022880158c8fc49563f32 112.14483 112.14483 32.048559999999995 32.048559999999995
# 当前计算第 2475 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58d24bec0158d8b427d133f4 :全部数据点： 86 个：可用数据点： 65 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58d24bec0158d8b427d133f4 ,计算点数量： 65 ,成员点数量： 34 ,核心点数量： 34 ,非核心点数量： 0 ,噪音点数量： 31
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58d24bec0158d8b427d133f4 112.15520500000001 112.15511000000001 32.05061 32.05061
# 当前计算第 2476 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58f7b984015906d89c4574f9 :全部数据点： 41 个：可用数据点： 28 个：异常数据点: 13 个
# 当前计算第 2477 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca58f7b984015906df178d7d6e :全部数据点： 150 个：可用数据点： 113 个：异常数据点: 37 个
# 当前计算第 2478 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a5997323206 :全部数据点： 65 个：可用数据点： 26 个：异常数据点: 39 个
# 当前计算第 2479 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b31948 :全部数据点： 43 个：可用数据点： 26 个：异常数据点: 17 个
# 当前计算第 2480 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32528 :全部数据点： 103 个：可用数据点： 85 个：异常数据点: 18 个
# 当前计算第 2481 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32548 :全部数据点： 51 个：可用数据点： 43 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32548 ,计算点数量： 43 ,成员点数量： 24 ,核心点数量： 24 ,非核心点数量： 0 ,噪音点数量： 19
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32548 110.78499599999999 110.78499599999999 32.666472999999996 32.666472999999996
# 当前计算第 2482 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32657 :全部数据点： 354 个：可用数据点： 279 个：异常数据点: 75 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32657 ,计算点数量： 279 ,成员点数量： 225 ,核心点数量： 225 ,非核心点数量： 0 ,噪音点数量： 54
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32657 110.77221000000002 110.772194 32.668427 32.66838
# 当前计算第 2483 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32939 :全部数据点： 74 个：可用数据点： 59 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32939 ,计算点数量： 59 ,成员点数量： 33 ,核心点数量： 33 ,非核心点数量： 0 ,噪音点数量： 26
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32939 114.90467 114.90467 30.404388 30.404388
# 当前计算第 2484 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32941 :全部数据点： 90 个：可用数据点： 66 个：异常数据点: 24 个
# 当前计算第 2485 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b32943 :全部数据点： 54 个：可用数据点： 37 个：异常数据点: 17 个
# 当前计算第 2486 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74ca59262e4101593a69d2b33273 :全部数据点： 56 个：可用数据点： 45 个：异常数据点: 11 个

# %%
xqwz = pd.DataFrame(xq_code_list)
xqwz['east_longitude'] = pd.DataFrame(pre_night_longitude_max_list)
xqwz['west_longitude'] = pd.DataFrame(pre_night_longitude_min_list)
xqwz['north_latitude'] = pd.DataFrame(pre_night_latitude_max_list)
xqwz['south_latitude'] = pd.DataFrame(pre_night_latitude_min_list)

# %%
xqwz.to_csv('D:/data/sun/dbscan/xqwz.csv')
print('end')
# Out:
# end
