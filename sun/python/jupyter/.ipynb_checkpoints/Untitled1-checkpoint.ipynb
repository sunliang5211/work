# %%
import pandas as pd

# %%
train_savepath = '/home/hb_liulian/data/sunliang/data_05'
df = pd.read_csv(train_savepath + '/liwang_user_05.csv')
print(df.shape[0])
l = [0 for i in range(df.shape[0])]
df['label'] = l
df.to_csv(train_savepath + '/liwang_user_05_label.csv')
print('end')
# Out:
# 655661
# ...
