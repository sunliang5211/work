# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt  
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %%
jwddf = pd.read_csv('D:/data/sun/dbscan/jwd_all.csv')

xqwz = pd.DataFrame({'xq_code':'','east_longitude':'','west_longitude':'','north_latitude':'','south_latitude':''},pd.Index(range(1)))
xq_code_list = []
pre_night_longitude_max_list = []
pre_night_longitude_min_list = []
pre_night_latitude_max_list = []
pre_night_latitude_min_list = []

# %%
def showAllPointImage(jwd,xq_code):
    plt.scatter(jwd['pre_night_longitude'], jwd['pre_night_latitude'], c="red", marker='.', label=xq_code) 
    plt.xlabel('longitude')  
    plt.ylabel('latitude')  
    plt.legend(loc=2)  
    plt.show() 
    
def showCalPointImage(test_df,xq_code):
    plt.scatter(test_df['pre_night_longitude'], test_df['pre_night_latitude'], c="red", marker='.', label=xq_code) 
    plt.xlabel('longitude')  
    plt.ylabel('latitude')  
    plt.legend(loc=2)  
    plt.show() 
    
def showClusterImage(core_member,non_core_member,noise_member,n_clusters_):
    plt.plot(core_member['pre_night_longitude'], core_member['pre_night_latitude'], '+', markersize=6)
    plt.plot(non_core_member['pre_night_longitude'], non_core_member['pre_night_latitude'], '^', markersize=6)
    plt.plot(noise_member['pre_night_longitude'], noise_member['pre_night_latitude'], '.', markersize=6)
    plt.title('Estimated number of clusters: %d' % n_clusters_)
    plt.show()
    
def showMemberImage(xy,xq_code):
    plt.scatter(xy['pre_night_longitude'], xy['pre_night_latitude'], c="red", marker='.', label=xq_code) 
    plt.xlabel('longitude')  
    plt.ylabel('latitude')  
    plt.legend(loc=2)  
    plt.show() 
    
def calMedian(jwd):
    longitude_zws = jwd['pre_night_longitude'].median()
    latitude_zws = jwd['pre_night_latitude'].median()
    return longitude_zws,latitude_zws
    
def calMean(jwd):
    longitude_pjs = jwd['pre_night_longitude'].mean()
    latitude_pjs = jwd['pre_night_latitude'].mean()
    return longitude_pjs,latitude_pjs

def filterExcepValues(jwd,xq_code):
    longitude_zws,latitude_zws = calMedian(jwd)
    test_df = jwd[(jwd.pre_night_longitude > longitude_zws - 0.025) &
        (jwd.pre_night_longitude < longitude_zws + 0.025) &
        (jwd.pre_night_latitude > latitude_zws - 0.025) &
        (jwd.pre_night_latitude < latitude_zws + 0.025)]
    
    excep_num = jwd.shape[0] - test_df.shape[0]
    print('xq_code：',xq_code ,':全部数据点：',jwd.shape[0],'个：可用数据点：',test_df.shape[0],'个：异常数据点:',excep_num,'个')
    return test_df

def dbscan(test_df,eps1,min_samples1):
    db = DBSCAN(eps=eps1, min_samples=min_samples1).fit(test_df[['pre_night_longitude','pre_night_latitude']])
    labels = db.labels_
    #计算簇个数
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    return db,n_clusters_,labels

def call(df,eps):
    i = 0
    jwddf_groupby = df.groupby(by = 'xq_code')
    xq_codes = list(jwddf_groupby.groups.keys())
    otherdf = pd.DataFrame()
    for xq_code in xq_codes:
        i += 1
        print("当前计算第",i,"个小区")
        jwd = df.loc[df['xq_code']==xq_code]
        index = range(df.shape[0])

        #展示全部用户位置分布
        #showAllPointImage(jwd,xq_code)

        #剔除异常值
        test_df = filterExcepValues(jwd,xq_code)

        #展示参与计算的用户的位置分布
        #showCalPointImage(test_df,xq_code)

        if test_df.shape[0] != 0:
            #db,n_clusters_,labels = dbscan(test_df,eps1,round(test_df.shape[0] * 0.4))
            db,n_clusters_,labels = dbscan(test_df,eps,round(test_df.shape[0] * 0.4))

            if n_clusters_ == 1:
                core_samples_mask = np.zeros_like(labels, dtype=bool)
                #核心点
                core_samples_mask[db.core_sample_indices_] = True
                #成员点
                class_member_mask = (labels == 0)
                #噪声点
                noise_member_mask = (labels == -1)

                core_member = test_df[class_member_mask & core_samples_mask]
                non_core_member = test_df[class_member_mask & ~core_samples_mask]
                class_member = test_df[class_member_mask]
                noise_member = test_df[noise_member_mask]


                #展示簇分布
                #showClusterImage(core_member,non_core_member,noise_member,n_clusters_)
                #展示成员点分布
                #showMemberImage(class_member,xq_code)

                #print('xq_code：',xq_code,',计算点数量：',test_df.shape[0],',成员点数量：',class_member.shape[0],',核心点数量：',core_member.shape[0],',非核心点数量：',non_core_member.shape[0],',噪音点数量：',noise_member.shape[0])
                #print('xq_code：',xq_code,class_member['pre_night_longitude'].max(),class_member['pre_night_longitude'].min(),class_member['pre_night_latitude'].max(),class_member['pre_night_latitude'].min()) 

                east = class_member['pre_night_longitude'].max()
                west = class_member['pre_night_longitude'].min()
                north = class_member['pre_night_latitude'].max()
                south = class_member['pre_night_latitude'].min()

                if (east - west) > 0.0005 and (north - south) > 0.0005:
                    xq_code_list.append(xq_code)
                    pre_night_longitude_max_list.append(east)
                    pre_night_longitude_min_list.append(west)
                    pre_night_latitude_max_list.append(north)
                    pre_night_latitude_min_list.append(south)
                else:
                    #print(df[df.xq_code == xq_code])
                    otherdf = otherdf.append(df[df.xq_code == xq_code],ignore_index=True)
                    #pass
                    print('xq_code：',xq_code ,'小区范围大小，重新计算')

            else:
                otherdf = otherdf.append(df[df.xq_code == xq_code],ignore_index=True)
                #pass
                print('xq_code：',xq_code ,'计算簇个数为',n_clusters_,'个，稍后计算！')

        else:
            pass
            #print('xq_code：',xq_code ,':可用数据点为',test_df.shape[0],'个，稍后计算！')
    
    print('otherdf.shape',otherdf.shape)
    print(otherdf)
    
    if otherdf.shape[0] != 0:
        eps += 0.001
        print('eps=',eps)
        if eps <= 0.01:
            call(otherdf,eps)
        else:
           return
    else:
        return

# %%
call(jwddf,0.001)
# Out:
# 当前计算第 1 个小区
# xq_code： BUSINESS_COMMUNITY-0000000054995ac90154aa61edf80042 :全部数据点： 84 个：可用数据点： 63 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-0000000054995ac90154aa61edf80042 计算簇个数为 0 个，稍后计算！
# 当前计算第 2 个小区
# xq_code： BUSINESS_COMMUNITY-141450066916 :全部数据点： 139 个：可用数据点： 79 个：异常数据点: 60 个
# xq_code： BUSINESS_COMMUNITY-141450066916 小区范围大小，重新计算
# 当前计算第 3 个小区
# xq_code： BUSINESS_COMMUNITY-141450067347 :全部数据点： 86 个：可用数据点： 64 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450067347 计算簇个数为 0 个，稍后计算！
# 当前计算第 4 个小区
# xq_code： BUSINESS_COMMUNITY-141450067362 :全部数据点： 94 个：可用数据点： 61 个：异常数据点: 33 个
# xq_code： BUSINESS_COMMUNITY-141450067362 计算簇个数为 0 个，稍后计算！
# 当前计算第 5 个小区
# xq_code： BUSINESS_COMMUNITY-141450067369 :全部数据点： 64 个：可用数据点： 49 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450067369 计算簇个数为 0 个，稍后计算！
# 当前计算第 6 个小区
# xq_code： BUSINESS_COMMUNITY-141450067372 :全部数据点： 96 个：可用数据点： 73 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450067372 小区范围大小，重新计算
# 当前计算第 7 个小区
# xq_code： BUSINESS_COMMUNITY-141450067384 :全部数据点： 85 个：可用数据点： 57 个：异常数据点: 28 个
# xq_code： BUSINESS_COMMUNITY-141450067384 计算簇个数为 0 个，稍后计算！
# 当前计算第 8 个小区
# xq_code： BUSINESS_COMMUNITY-141450067390 :全部数据点： 62 个：可用数据点： 39 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450067390 计算簇个数为 0 个，稍后计算！
# 当前计算第 9 个小区
# xq_code： BUSINESS_COMMUNITY-141450067407 :全部数据点： 60 个：可用数据点： 50 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-141450067407 小区范围大小，重新计算
# 当前计算第 10 个小区
# xq_code： BUSINESS_COMMUNITY-141450067427 :全部数据点： 70 个：可用数据点： 46 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450067427 计算簇个数为 0 个，稍后计算！
# 当前计算第 11 个小区
# xq_code： BUSINESS_COMMUNITY-141450067471 :全部数据点： 51 个：可用数据点： 42 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141450067471 小区范围大小，重新计算
# 当前计算第 12 个小区
# xq_code： BUSINESS_COMMUNITY-141450067513 :全部数据点： 70 个：可用数据点： 50 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450067513 计算簇个数为 0 个，稍后计算！
# 当前计算第 13 个小区
# xq_code： BUSINESS_COMMUNITY-141450067537 :全部数据点： 58 个：可用数据点： 41 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450067537 计算簇个数为 0 个，稍后计算！
# 当前计算第 14 个小区
# xq_code： BUSINESS_COMMUNITY-141450067538 :全部数据点： 69 个：可用数据点： 55 个：异常数据点: 14 个
# 当前计算第 15 个小区
# xq_code： BUSINESS_COMMUNITY-141450067551 :全部数据点： 77 个：可用数据点： 51 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-141450067551 计算簇个数为 0 个，稍后计算！
# 当前计算第 16 个小区
# xq_code： BUSINESS_COMMUNITY-141450067555 :全部数据点： 76 个：可用数据点： 56 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450067555 计算簇个数为 0 个，稍后计算！
# 当前计算第 17 个小区
# xq_code： BUSINESS_COMMUNITY-141450067587 :全部数据点： 60 个：可用数据点： 39 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450067587 计算簇个数为 0 个，稍后计算！
# 当前计算第 18 个小区
# xq_code： BUSINESS_COMMUNITY-141450067589 :全部数据点： 53 个：可用数据点： 41 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450067589 计算簇个数为 0 个，稍后计算！
# 当前计算第 19 个小区
# xq_code： BUSINESS_COMMUNITY-141450067603 :全部数据点： 57 个：可用数据点： 33 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450067603 计算簇个数为 0 个，稍后计算！
# 当前计算第 20 个小区
# xq_code： BUSINESS_COMMUNITY-141450067607 :全部数据点： 53 个：可用数据点： 34 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450067607 计算簇个数为 0 个，稍后计算！
# 当前计算第 21 个小区
# xq_code： BUSINESS_COMMUNITY-141450067614 :全部数据点： 99 个：可用数据点： 53 个：异常数据点: 46 个
# xq_code： BUSINESS_COMMUNITY-141450067614 小区范围大小，重新计算
# 当前计算第 22 个小区
# xq_code： BUSINESS_COMMUNITY-141450067630 :全部数据点： 51 个：可用数据点： 24 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-141450067630 小区范围大小，重新计算
# 当前计算第 23 个小区
# xq_code： BUSINESS_COMMUNITY-141450067792 :全部数据点： 58 个：可用数据点： 33 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450067792 计算簇个数为 0 个，稍后计算！
# 当前计算第 24 个小区
# xq_code： BUSINESS_COMMUNITY-141450067971 :全部数据点： 71 个：可用数据点： 49 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450067971 小区范围大小，重新计算
# 当前计算第 25 个小区
# xq_code： BUSINESS_COMMUNITY-141450067972 :全部数据点： 56 个：可用数据点： 48 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450067972 计算簇个数为 0 个，稍后计算！
# 当前计算第 26 个小区
# xq_code： BUSINESS_COMMUNITY-141450068127 :全部数据点： 164 个：可用数据点： 110 个：异常数据点: 54 个
# xq_code： BUSINESS_COMMUNITY-141450068127 小区范围大小，重新计算
# 当前计算第 27 个小区
# xq_code： BUSINESS_COMMUNITY-141450068148 :全部数据点： 86 个：可用数据点： 62 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450068148 小区范围大小，重新计算
# 当前计算第 28 个小区
# xq_code： BUSINESS_COMMUNITY-141450068158 :全部数据点： 70 个：可用数据点： 46 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450068158 计算簇个数为 0 个，稍后计算！
# 当前计算第 29 个小区
# xq_code： BUSINESS_COMMUNITY-141450068163 :全部数据点： 135 个：可用数据点： 113 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450068163 计算簇个数为 0 个，稍后计算！
# 当前计算第 30 个小区
# xq_code： BUSINESS_COMMUNITY-141450068245 :全部数据点： 46 个：可用数据点： 26 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450068245 小区范围大小，重新计算
# 当前计算第 31 个小区
# xq_code： BUSINESS_COMMUNITY-141450068488 :全部数据点： 146 个：可用数据点： 104 个：异常数据点: 42 个
# xq_code： BUSINESS_COMMUNITY-141450068488 计算簇个数为 0 个，稍后计算！
# 当前计算第 32 个小区
# xq_code： BUSINESS_COMMUNITY-141450068787 :全部数据点： 27 个：可用数据点： 22 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450068787 小区范围大小，重新计算
# 当前计算第 33 个小区
# xq_code： BUSINESS_COMMUNITY-141450068794 :全部数据点： 67 个：可用数据点： 54 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450068794 小区范围大小，重新计算
# 当前计算第 34 个小区
# xq_code： BUSINESS_COMMUNITY-141450069533 :全部数据点： 118 个：可用数据点： 88 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-141450069533 计算簇个数为 0 个，稍后计算！
# 当前计算第 35 个小区
# xq_code： BUSINESS_COMMUNITY-141450069613 :全部数据点： 117 个：可用数据点： 85 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450069613 小区范围大小，重新计算
# 当前计算第 36 个小区
# xq_code： BUSINESS_COMMUNITY-141450069770 :全部数据点： 151 个：可用数据点： 129 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450069770 计算簇个数为 0 个，稍后计算！
# 当前计算第 37 个小区
# xq_code： BUSINESS_COMMUNITY-141450069780 :全部数据点： 85 个：可用数据点： 65 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450069780 小区范围大小，重新计算
# 当前计算第 38 个小区
# xq_code： BUSINESS_COMMUNITY-141450069821 :全部数据点： 90 个：可用数据点： 74 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450069821 小区范围大小，重新计算
# 当前计算第 39 个小区
# xq_code： BUSINESS_COMMUNITY-141450069833 :全部数据点： 46 个：可用数据点： 41 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450069833 小区范围大小，重新计算
# 当前计算第 40 个小区
# xq_code： BUSINESS_COMMUNITY-141450069834 :全部数据点： 48 个：可用数据点： 39 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141450069834 计算簇个数为 0 个，稍后计算！
# 当前计算第 41 个小区
# xq_code： BUSINESS_COMMUNITY-141450069931 :全部数据点： 91 个：可用数据点： 71 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450069931 计算簇个数为 0 个，稍后计算！
# 当前计算第 42 个小区
# xq_code： BUSINESS_COMMUNITY-141450069970 :全部数据点： 53 个：可用数据点： 32 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450069970 计算簇个数为 0 个，稍后计算！
# 当前计算第 43 个小区
# xq_code： BUSINESS_COMMUNITY-141450070018 :全部数据点： 110 个：可用数据点： 88 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450070018 小区范围大小，重新计算
# 当前计算第 44 个小区
# xq_code： BUSINESS_COMMUNITY-141450070021 :全部数据点： 85 个：可用数据点： 53 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450070021 计算簇个数为 0 个，稍后计算！
# 当前计算第 45 个小区
# xq_code： BUSINESS_COMMUNITY-141450070025 :全部数据点： 129 个：可用数据点： 93 个：异常数据点: 36 个
# xq_code： BUSINESS_COMMUNITY-141450070025 小区范围大小，重新计算
# 当前计算第 46 个小区
# xq_code： BUSINESS_COMMUNITY-141450070058 :全部数据点： 51 个：可用数据点： 46 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450070058 小区范围大小，重新计算
# 当前计算第 47 个小区
# xq_code： BUSINESS_COMMUNITY-141450070075 :全部数据点： 128 个：可用数据点： 106 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450070075 小区范围大小，重新计算
# 当前计算第 48 个小区
# xq_code： BUSINESS_COMMUNITY-141450070102 :全部数据点： 139 个：可用数据点： 112 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-141450070102 计算簇个数为 0 个，稍后计算！
# 当前计算第 49 个小区
# xq_code： BUSINESS_COMMUNITY-141450070131 :全部数据点： 105 个：可用数据点： 66 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-141450070131 计算簇个数为 0 个，稍后计算！
# 当前计算第 50 个小区
# xq_code： BUSINESS_COMMUNITY-141450070151 :全部数据点： 154 个：可用数据点： 133 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450070151 计算簇个数为 0 个，稍后计算！
# 当前计算第 51 个小区
# xq_code： BUSINESS_COMMUNITY-141450070187 :全部数据点： 123 个：可用数据点： 90 个：异常数据点: 33 个
# xq_code： BUSINESS_COMMUNITY-141450070187 计算簇个数为 0 个，稍后计算！
# 当前计算第 52 个小区
# xq_code： BUSINESS_COMMUNITY-141450070298 :全部数据点： 53 个：可用数据点： 40 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450070298 计算簇个数为 0 个，稍后计算！
# 当前计算第 53 个小区
# xq_code： BUSINESS_COMMUNITY-141450070420 :全部数据点： 32 个：可用数据点： 28 个：异常数据点: 4 个
# xq_code： BUSINESS_COMMUNITY-141450070420 计算簇个数为 0 个，稍后计算！
# 当前计算第 54 个小区
# xq_code： BUSINESS_COMMUNITY-141450070423 :全部数据点： 98 个：可用数据点： 76 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450070423 小区范围大小，重新计算
# 当前计算第 55 个小区
# xq_code： BUSINESS_COMMUNITY-141450070464 :全部数据点： 78 个：可用数据点： 60 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450070464 小区范围大小，重新计算
# 当前计算第 56 个小区
# xq_code： BUSINESS_COMMUNITY-141450070520 :全部数据点： 48 个：可用数据点： 40 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450070520 计算簇个数为 0 个，稍后计算！
# 当前计算第 57 个小区
# xq_code： BUSINESS_COMMUNITY-141450070604 :全部数据点： 90 个：可用数据点： 70 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450070604 小区范围大小，重新计算
# 当前计算第 58 个小区
# xq_code： BUSINESS_COMMUNITY-141450070627 :全部数据点： 78 个：可用数据点： 70 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450070627 计算簇个数为 0 个，稍后计算！
# 当前计算第 59 个小区
# xq_code： BUSINESS_COMMUNITY-141450070633 :全部数据点： 68 个：可用数据点： 55 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450070633 小区范围大小，重新计算
# 当前计算第 60 个小区
# xq_code： BUSINESS_COMMUNITY-141450070638 :全部数据点： 67 个：可用数据点： 59 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450070638 小区范围大小，重新计算
# 当前计算第 61 个小区
# xq_code： BUSINESS_COMMUNITY-141450070690 :全部数据点： 69 个：可用数据点： 41 个：异常数据点: 28 个
# xq_code： BUSINESS_COMMUNITY-141450070690 小区范围大小，重新计算
# 当前计算第 62 个小区
# xq_code： BUSINESS_COMMUNITY-141450070701 :全部数据点： 31 个：可用数据点： 24 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450070701 计算簇个数为 0 个，稍后计算！
# 当前计算第 63 个小区
# xq_code： BUSINESS_COMMUNITY-141450070704 :全部数据点： 60 个：可用数据点： 46 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450070704 计算簇个数为 0 个，稍后计算！
# 当前计算第 64 个小区
# xq_code： BUSINESS_COMMUNITY-141450070715 :全部数据点： 48 个：可用数据点： 39 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141450070715 计算簇个数为 0 个，稍后计算！
# 当前计算第 65 个小区
# xq_code： BUSINESS_COMMUNITY-141450070762 :全部数据点： 94 个：可用数据点： 77 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450070762 计算簇个数为 0 个，稍后计算！
# 当前计算第 66 个小区
# xq_code： BUSINESS_COMMUNITY-141450070802 :全部数据点： 38 个：可用数据点： 25 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450070802 计算簇个数为 0 个，稍后计算！
# 当前计算第 67 个小区
# xq_code： BUSINESS_COMMUNITY-141450070803 :全部数据点： 45 个：可用数据点： 38 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450070803 小区范围大小，重新计算
# 当前计算第 68 个小区
# xq_code： BUSINESS_COMMUNITY-141450070833 :全部数据点： 29 个：可用数据点： 20 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141450070833 小区范围大小，重新计算
# 当前计算第 69 个小区
# xq_code： BUSINESS_COMMUNITY-141450070841 :全部数据点： 58 个：可用数据点： 42 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450070841 小区范围大小，重新计算
# 当前计算第 70 个小区
# xq_code： BUSINESS_COMMUNITY-141450070851 :全部数据点： 40 个：可用数据点： 35 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450070851 计算簇个数为 0 个，稍后计算！
# 当前计算第 71 个小区
# xq_code： BUSINESS_COMMUNITY-141450070864 :全部数据点： 65 个：可用数据点： 58 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450070864 小区范围大小，重新计算
# 当前计算第 72 个小区
# xq_code： BUSINESS_COMMUNITY-141450070880 :全部数据点： 71 个：可用数据点： 39 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450070880 小区范围大小，重新计算
# 当前计算第 73 个小区
# xq_code： BUSINESS_COMMUNITY-141450071030 :全部数据点： 92 个：可用数据点： 68 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450071030 计算簇个数为 0 个，稍后计算！
# 当前计算第 74 个小区
# xq_code： BUSINESS_COMMUNITY-141450071036 :全部数据点： 109 个：可用数据点： 83 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-141450071036 小区范围大小，重新计算
# 当前计算第 75 个小区
# xq_code： BUSINESS_COMMUNITY-141450071046 :全部数据点： 162 个：可用数据点： 122 个：异常数据点: 40 个
# xq_code： BUSINESS_COMMUNITY-141450071046 小区范围大小，重新计算
# 当前计算第 76 个小区
# xq_code： BUSINESS_COMMUNITY-141450071096 :全部数据点： 95 个：可用数据点： 78 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450071096 小区范围大小，重新计算
# 当前计算第 77 个小区
# xq_code： BUSINESS_COMMUNITY-141450071100 :全部数据点： 72 个：可用数据点： 56 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450071100 小区范围大小，重新计算
# 当前计算第 78 个小区
# xq_code： BUSINESS_COMMUNITY-141450071114 :全部数据点： 174 个：可用数据点： 125 个：异常数据点: 49 个
# xq_code： BUSINESS_COMMUNITY-141450071114 小区范围大小，重新计算
# 当前计算第 79 个小区
# xq_code： BUSINESS_COMMUNITY-141450071163 :全部数据点： 128 个：可用数据点： 106 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450071163 计算簇个数为 0 个，稍后计算！
# 当前计算第 80 个小区
# xq_code： BUSINESS_COMMUNITY-141450071171 :全部数据点： 100 个：可用数据点： 77 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450071171 小区范围大小，重新计算
# 当前计算第 81 个小区
# xq_code： BUSINESS_COMMUNITY-141450071172 :全部数据点： 162 个：可用数据点： 135 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-141450071172 计算簇个数为 0 个，稍后计算！
# 当前计算第 82 个小区
# xq_code： BUSINESS_COMMUNITY-141450071290 :全部数据点： 88 个：可用数据点： 68 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450071290 计算簇个数为 0 个，稍后计算！
# 当前计算第 83 个小区
# xq_code： BUSINESS_COMMUNITY-141450071304 :全部数据点： 148 个：可用数据点： 119 个：异常数据点: 29 个
# xq_code： BUSINESS_COMMUNITY-141450071304 计算簇个数为 0 个，稍后计算！
# 当前计算第 84 个小区
# xq_code： BUSINESS_COMMUNITY-141450071352 :全部数据点： 96 个：可用数据点： 67 个：异常数据点: 29 个
# xq_code： BUSINESS_COMMUNITY-141450071352 计算簇个数为 0 个，稍后计算！
# 当前计算第 85 个小区
# xq_code： BUSINESS_COMMUNITY-141450071360 :全部数据点： 171 个：可用数据点： 132 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-141450071360 小区范围大小，重新计算
# 当前计算第 86 个小区
# xq_code： BUSINESS_COMMUNITY-141450071472 :全部数据点： 104 个：可用数据点： 78 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-141450071472 计算簇个数为 0 个，稍后计算！
# 当前计算第 87 个小区
# xq_code： BUSINESS_COMMUNITY-141450071505 :全部数据点： 51 个：可用数据点： 38 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450071505 计算簇个数为 0 个，稍后计算！
# 当前计算第 88 个小区
# xq_code： BUSINESS_COMMUNITY-141450071561 :全部数据点： 259 个：可用数据点： 210 个：异常数据点: 49 个
# xq_code： BUSINESS_COMMUNITY-141450071561 计算簇个数为 0 个，稍后计算！
# 当前计算第 89 个小区
# xq_code： BUSINESS_COMMUNITY-141450071595 :全部数据点： 124 个：可用数据点： 82 个：异常数据点: 42 个
# xq_code： BUSINESS_COMMUNITY-141450071595 小区范围大小，重新计算
# 当前计算第 90 个小区
# xq_code： BUSINESS_COMMUNITY-141450071656 :全部数据点： 108 个：可用数据点： 78 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-141450071656 小区范围大小，重新计算
# 当前计算第 91 个小区
# xq_code： BUSINESS_COMMUNITY-141450071659 :全部数据点： 144 个：可用数据点： 99 个：异常数据点: 45 个
# xq_code： BUSINESS_COMMUNITY-141450071659 小区范围大小，重新计算
# 当前计算第 92 个小区
# xq_code： BUSINESS_COMMUNITY-141450071664 :全部数据点： 162 个：可用数据点： 130 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450071664 计算簇个数为 0 个，稍后计算！
# 当前计算第 93 个小区
# xq_code： BUSINESS_COMMUNITY-141450071665 :全部数据点： 159 个：可用数据点： 125 个：异常数据点: 34 个
# xq_code： BUSINESS_COMMUNITY-141450071665 计算簇个数为 0 个，稍后计算！
# 当前计算第 94 个小区
# xq_code： BUSINESS_COMMUNITY-141450071670 :全部数据点： 46 个：可用数据点： 38 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450071670 计算簇个数为 0 个，稍后计算！
# 当前计算第 95 个小区
# xq_code： BUSINESS_COMMUNITY-141450071756 :全部数据点： 161 个：可用数据点： 127 个：异常数据点: 34 个
# xq_code： BUSINESS_COMMUNITY-141450071756 小区范围大小，重新计算
# 当前计算第 96 个小区
# xq_code： BUSINESS_COMMUNITY-141450071763 :全部数据点： 48 个：可用数据点： 30 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450071763 小区范围大小，重新计算
# 当前计算第 97 个小区
# xq_code： BUSINESS_COMMUNITY-141450071764 :全部数据点： 104 个：可用数据点： 68 个：异常数据点: 36 个
# xq_code： BUSINESS_COMMUNITY-141450071764 小区范围大小，重新计算
# 当前计算第 98 个小区
# xq_code： BUSINESS_COMMUNITY-141450071770 :全部数据点： 79 个：可用数据点： 65 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450071770 计算簇个数为 0 个，稍后计算！
# 当前计算第 99 个小区
# xq_code： BUSINESS_COMMUNITY-141450071804 :全部数据点： 97 个：可用数据点： 7 个：异常数据点: 90 个
# xq_code： BUSINESS_COMMUNITY-141450071804 小区范围大小，重新计算
# 当前计算第 100 个小区
# xq_code： BUSINESS_COMMUNITY-141450071821 :全部数据点： 65 个：可用数据点： 33 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450071821 小区范围大小，重新计算
# 当前计算第 101 个小区
# xq_code： BUSINESS_COMMUNITY-141450071853 :全部数据点： 250 个：可用数据点： 196 个：异常数据点: 54 个
# 当前计算第 102 个小区
# xq_code： BUSINESS_COMMUNITY-141450071856 :全部数据点： 45 个：可用数据点： 37 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450071856 小区范围大小，重新计算
# 当前计算第 103 个小区
# xq_code： BUSINESS_COMMUNITY-141450071940 :全部数据点： 70 个：可用数据点： 59 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450071940 计算簇个数为 0 个，稍后计算！
# 当前计算第 104 个小区
# xq_code： BUSINESS_COMMUNITY-141450071984 :全部数据点： 129 个：可用数据点： 84 个：异常数据点: 45 个
# xq_code： BUSINESS_COMMUNITY-141450071984 计算簇个数为 0 个，稍后计算！
# 当前计算第 105 个小区
# xq_code： BUSINESS_COMMUNITY-141450072000 :全部数据点： 65 个：可用数据点： 48 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450072000 计算簇个数为 0 个，稍后计算！
# 当前计算第 106 个小区
# xq_code： BUSINESS_COMMUNITY-141450072025 :全部数据点： 61 个：可用数据点： 47 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450072025 小区范围大小，重新计算
# 当前计算第 107 个小区
# xq_code： BUSINESS_COMMUNITY-141450072031 :全部数据点： 105 个：可用数据点： 75 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-141450072031 小区范围大小，重新计算
# 当前计算第 108 个小区
# xq_code： BUSINESS_COMMUNITY-141450072086 :全部数据点： 65 个：可用数据点： 48 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450072086 小区范围大小，重新计算
# 当前计算第 109 个小区
# xq_code： BUSINESS_COMMUNITY-141450072098 :全部数据点： 53 个：可用数据点： 38 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450072098 小区范围大小，重新计算
# 当前计算第 110 个小区
# xq_code： BUSINESS_COMMUNITY-141450072099 :全部数据点： 169 个：可用数据点： 131 个：异常数据点: 38 个
# 当前计算第 111 个小区
# xq_code： BUSINESS_COMMUNITY-141450072119 :全部数据点： 127 个：可用数据点： 103 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450072119 小区范围大小，重新计算
# 当前计算第 112 个小区
# xq_code： BUSINESS_COMMUNITY-141450072133 :全部数据点： 132 个：可用数据点： 93 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-141450072133 小区范围大小，重新计算
# 当前计算第 113 个小区
# xq_code： BUSINESS_COMMUNITY-141450072248 :全部数据点： 63 个：可用数据点： 46 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450072248 计算簇个数为 0 个，稍后计算！
# 当前计算第 114 个小区
# xq_code： BUSINESS_COMMUNITY-141450072257 :全部数据点： 65 个：可用数据点： 51 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450072257 计算簇个数为 0 个，稍后计算！
# 当前计算第 115 个小区
# xq_code： BUSINESS_COMMUNITY-141450072327 :全部数据点： 57 个：可用数据点： 44 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450072327 小区范围大小，重新计算
# 当前计算第 116 个小区
# xq_code： BUSINESS_COMMUNITY-141450072337 :全部数据点： 69 个：可用数据点： 49 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450072337 计算簇个数为 0 个，稍后计算！
# 当前计算第 117 个小区
# xq_code： BUSINESS_COMMUNITY-141450072338 :全部数据点： 96 个：可用数据点： 48 个：异常数据点: 48 个
# xq_code： BUSINESS_COMMUNITY-141450072338 计算簇个数为 0 个，稍后计算！
# 当前计算第 118 个小区
# xq_code： BUSINESS_COMMUNITY-141450072346 :全部数据点： 116 个：可用数据点： 85 个：异常数据点: 31 个
# xq_code： BUSINESS_COMMUNITY-141450072346 小区范围大小，重新计算
# 当前计算第 119 个小区
# xq_code： BUSINESS_COMMUNITY-141450072349 :全部数据点： 68 个：可用数据点： 43 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450072349 小区范围大小，重新计算
# 当前计算第 120 个小区
# xq_code： BUSINESS_COMMUNITY-141450072373 :全部数据点： 63 个：可用数据点： 51 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450072373 小区范围大小，重新计算
# 当前计算第 121 个小区
# xq_code： BUSINESS_COMMUNITY-141450072543 :全部数据点： 69 个：可用数据点： 54 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450072543 计算簇个数为 0 个，稍后计算！
# 当前计算第 122 个小区
# xq_code： BUSINESS_COMMUNITY-141450072547 :全部数据点： 64 个：可用数据点： 45 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450072547 小区范围大小，重新计算
# 当前计算第 123 个小区
# xq_code： BUSINESS_COMMUNITY-141450072548 :全部数据点： 81 个：可用数据点： 56 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450072548 小区范围大小，重新计算
# 当前计算第 124 个小区
# xq_code： BUSINESS_COMMUNITY-141450072553 :全部数据点： 127 个：可用数据点： 80 个：异常数据点: 47 个
# xq_code： BUSINESS_COMMUNITY-141450072553 小区范围大小，重新计算
# 当前计算第 125 个小区
# xq_code： BUSINESS_COMMUNITY-141450072558 :全部数据点： 93 个：可用数据点： 74 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450072558 小区范围大小，重新计算
# 当前计算第 126 个小区
# xq_code： BUSINESS_COMMUNITY-141450072563 :全部数据点： 125 个：可用数据点： 105 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450072563 计算簇个数为 0 个，稍后计算！
# 当前计算第 127 个小区
# xq_code： BUSINESS_COMMUNITY-141450072637 :全部数据点： 58 个：可用数据点： 45 个：异常数据点: 13 个
# 当前计算第 128 个小区
# xq_code： BUSINESS_COMMUNITY-141450072681 :全部数据点： 90 个：可用数据点： 66 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450072681 小区范围大小，重新计算
# 当前计算第 129 个小区
# xq_code： BUSINESS_COMMUNITY-141450072708 :全部数据点： 86 个：可用数据点： 67 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450072708 计算簇个数为 0 个，稍后计算！
# 当前计算第 130 个小区
# xq_code： BUSINESS_COMMUNITY-141450072717 :全部数据点： 62 个：可用数据点： 56 个：异常数据点: 6 个
# xq_code： BUSINESS_COMMUNITY-141450072717 计算簇个数为 0 个，稍后计算！
# 当前计算第 131 个小区
# xq_code： BUSINESS_COMMUNITY-141450072785 :全部数据点： 40 个：可用数据点： 26 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450072785 小区范围大小，重新计算
# 当前计算第 132 个小区
# xq_code： BUSINESS_COMMUNITY-141450072791 :全部数据点： 37 个：可用数据点： 26 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450072791 计算簇个数为 0 个，稍后计算！
# 当前计算第 133 个小区
# xq_code： BUSINESS_COMMUNITY-141450072862 :全部数据点： 67 个：可用数据点： 54 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450072862 小区范围大小，重新计算
# 当前计算第 134 个小区
# xq_code： BUSINESS_COMMUNITY-141450072901 :全部数据点： 82 个：可用数据点： 72 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-141450072901 小区范围大小，重新计算
# 当前计算第 135 个小区
# xq_code： BUSINESS_COMMUNITY-141450072985 :全部数据点： 27 个：可用数据点： 23 个：异常数据点: 4 个
# xq_code： BUSINESS_COMMUNITY-141450072985 小区范围大小，重新计算
# 当前计算第 136 个小区
# xq_code： BUSINESS_COMMUNITY-141450073011 :全部数据点： 109 个：可用数据点： 84 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450073011 计算簇个数为 0 个，稍后计算！
# 当前计算第 137 个小区
# xq_code： BUSINESS_COMMUNITY-141450073048 :全部数据点： 60 个：可用数据点： 40 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450073048 小区范围大小，重新计算
# 当前计算第 138 个小区
# xq_code： BUSINESS_COMMUNITY-141450073067 :全部数据点： 99 个：可用数据点： 72 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-141450073067 计算簇个数为 0 个，稍后计算！
# 当前计算第 139 个小区
# xq_code： BUSINESS_COMMUNITY-141450073069 :全部数据点： 75 个：可用数据点： 46 个：异常数据点: 29 个
# xq_code： BUSINESS_COMMUNITY-141450073069 计算簇个数为 0 个，稍后计算！
# 当前计算第 140 个小区
# xq_code： BUSINESS_COMMUNITY-141450073075 :全部数据点： 228 个：可用数据点： 159 个：异常数据点: 69 个
# xq_code： BUSINESS_COMMUNITY-141450073075 计算簇个数为 0 个，稍后计算！
# 当前计算第 141 个小区
# xq_code： BUSINESS_COMMUNITY-141450073125 :全部数据点： 144 个：可用数据点： 97 个：异常数据点: 47 个
# xq_code： BUSINESS_COMMUNITY-141450073125 计算簇个数为 0 个，稍后计算！
# 当前计算第 142 个小区
# xq_code： BUSINESS_COMMUNITY-141450073161 :全部数据点： 83 个：可用数据点： 65 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450073161 计算簇个数为 0 个，稍后计算！
# 当前计算第 143 个小区
# xq_code： BUSINESS_COMMUNITY-141450073171 :全部数据点： 52 个：可用数据点： 37 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450073171 小区范围大小，重新计算
# 当前计算第 144 个小区
# xq_code： BUSINESS_COMMUNITY-141450073173 :全部数据点： 77 个：可用数据点： 54 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450073173 小区范围大小，重新计算
# 当前计算第 145 个小区
# xq_code： BUSINESS_COMMUNITY-141450073176 :全部数据点： 47 个：可用数据点： 40 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450073176 计算簇个数为 0 个，稍后计算！
# 当前计算第 146 个小区
# xq_code： BUSINESS_COMMUNITY-141450073329 :全部数据点： 110 个：可用数据点： 91 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450073329 小区范围大小，重新计算
# 当前计算第 147 个小区
# xq_code： BUSINESS_COMMUNITY-141450073425 :全部数据点： 47 个：可用数据点： 39 个：异常数据点: 8 个
# 当前计算第 148 个小区
# xq_code： BUSINESS_COMMUNITY-141450073607 :全部数据点： 121 个：可用数据点： 106 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450073607 计算簇个数为 0 个，稍后计算！
# 当前计算第 149 个小区
# xq_code： BUSINESS_COMMUNITY-141450073747 :全部数据点： 384 个：可用数据点： 293 个：异常数据点: 91 个
# xq_code： BUSINESS_COMMUNITY-141450073747 计算簇个数为 0 个，稍后计算！
# 当前计算第 150 个小区
# xq_code： BUSINESS_COMMUNITY-141450075117 :全部数据点： 89 个：可用数据点： 64 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450075117 小区范围大小，重新计算
# 当前计算第 151 个小区
# xq_code： BUSINESS_COMMUNITY-141450076178 :全部数据点： 147 个：可用数据点： 97 个：异常数据点: 50 个
# xq_code： BUSINESS_COMMUNITY-141450076178 小区范围大小，重新计算
# 当前计算第 152 个小区
# xq_code： BUSINESS_COMMUNITY-141450076327 :全部数据点： 55 个：可用数据点： 43 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450076327 计算簇个数为 0 个，稍后计算！
# 当前计算第 153 个小区
# xq_code： BUSINESS_COMMUNITY-141450076331 :全部数据点： 70 个：可用数据点： 49 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450076331 计算簇个数为 0 个，稍后计算！
# 当前计算第 154 个小区
# xq_code： BUSINESS_COMMUNITY-141450076486 :全部数据点： 71 个：可用数据点： 48 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450076486 小区范围大小，重新计算
# 当前计算第 155 个小区
# xq_code： BUSINESS_COMMUNITY-141450076546 :全部数据点： 63 个：可用数据点： 48 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450076546 计算簇个数为 0 个，稍后计算！
# 当前计算第 156 个小区
# xq_code： BUSINESS_COMMUNITY-141450076550 :全部数据点： 20 个：可用数据点： 17 个：异常数据点: 3 个
# xq_code： BUSINESS_COMMUNITY-141450076550 小区范围大小，重新计算
# 当前计算第 157 个小区
# xq_code： BUSINESS_COMMUNITY-141450076603 :全部数据点： 36 个：可用数据点： 30 个：异常数据点: 6 个
# xq_code： BUSINESS_COMMUNITY-141450076603 小区范围大小，重新计算
# 当前计算第 158 个小区
# xq_code： BUSINESS_COMMUNITY-141450076891 :全部数据点： 57 个：可用数据点： 42 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450076891 计算簇个数为 0 个，稍后计算！
# 当前计算第 159 个小区
# xq_code： BUSINESS_COMMUNITY-141450076956 :全部数据点： 21 个：可用数据点： 17 个：异常数据点: 4 个
# xq_code： BUSINESS_COMMUNITY-141450076956 计算簇个数为 2 个，稍后计算！
# 当前计算第 160 个小区
# xq_code： BUSINESS_COMMUNITY-141450077018 :全部数据点： 161 个：可用数据点： 129 个：异常数据点: 32 个
# 当前计算第 161 个小区
# xq_code： BUSINESS_COMMUNITY-141450077036 :全部数据点： 47 个：可用数据点： 38 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141450077036 小区范围大小，重新计算
# 当前计算第 162 个小区
# xq_code： BUSINESS_COMMUNITY-141450077044 :全部数据点： 71 个：可用数据点： 53 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450077044 计算簇个数为 0 个，稍后计算！
# 当前计算第 163 个小区
# xq_code： BUSINESS_COMMUNITY-141450077046 :全部数据点： 50 个：可用数据点： 42 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450077046 计算簇个数为 0 个，稍后计算！
# 当前计算第 164 个小区
# xq_code： BUSINESS_COMMUNITY-141450077053 :全部数据点： 82 个：可用数据点： 69 个：异常数据点: 13 个
# 当前计算第 165 个小区
# xq_code： BUSINESS_COMMUNITY-141450077055 :全部数据点： 35 个：可用数据点： 29 个：异常数据点: 6 个
# xq_code： BUSINESS_COMMUNITY-141450077055 计算簇个数为 0 个，稍后计算！
# 当前计算第 166 个小区
# xq_code： BUSINESS_COMMUNITY-141450077070 :全部数据点： 85 个：可用数据点： 59 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-141450077070 小区范围大小，重新计算
# 当前计算第 167 个小区
# xq_code： BUSINESS_COMMUNITY-141450077108 :全部数据点： 73 个：可用数据点： 57 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450077108 计算簇个数为 0 个，稍后计算！
# 当前计算第 168 个小区
# xq_code： BUSINESS_COMMUNITY-141450077115 :全部数据点： 136 个：可用数据点： 98 个：异常数据点: 38 个
# xq_code： BUSINESS_COMMUNITY-141450077115 计算簇个数为 0 个，稍后计算！
# 当前计算第 169 个小区
# xq_code： BUSINESS_COMMUNITY-141450077137 :全部数据点： 267 个：可用数据点： 187 个：异常数据点: 80 个
# xq_code： BUSINESS_COMMUNITY-141450077137 计算簇个数为 0 个，稍后计算！
# 当前计算第 170 个小区
# xq_code： BUSINESS_COMMUNITY-141450077141 :全部数据点： 170 个：可用数据点： 109 个：异常数据点: 61 个
# xq_code： BUSINESS_COMMUNITY-141450077141 计算簇个数为 0 个，稍后计算！
# 当前计算第 171 个小区
# xq_code： BUSINESS_COMMUNITY-141450077150 :全部数据点： 139 个：可用数据点： 100 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-141450077150 计算簇个数为 0 个，稍后计算！
# 当前计算第 172 个小区
# xq_code： BUSINESS_COMMUNITY-141450077185 :全部数据点： 287 个：可用数据点： 192 个：异常数据点: 95 个
# xq_code： BUSINESS_COMMUNITY-141450077185 计算簇个数为 0 个，稍后计算！
# 当前计算第 173 个小区
# xq_code： BUSINESS_COMMUNITY-141450077195 :全部数据点： 185 个：可用数据点： 140 个：异常数据点: 45 个
# xq_code： BUSINESS_COMMUNITY-141450077195 计算簇个数为 0 个，稍后计算！
# 当前计算第 174 个小区
# xq_code： BUSINESS_COMMUNITY-141450077199 :全部数据点： 52 个：可用数据点： 39 个：异常数据点: 13 个
# 当前计算第 175 个小区
# xq_code： BUSINESS_COMMUNITY-141450077200 :全部数据点： 11 个：可用数据点： 9 个：异常数据点: 2 个
# xq_code： BUSINESS_COMMUNITY-141450077200 小区范围大小，重新计算
# 当前计算第 176 个小区
# xq_code： BUSINESS_COMMUNITY-141450077254 :全部数据点： 46 个：可用数据点： 0 个：异常数据点: 46 个
# 当前计算第 177 个小区
# xq_code： BUSINESS_COMMUNITY-141450077266 :全部数据点： 182 个：可用数据点： 0 个：异常数据点: 182 个
# 当前计算第 178 个小区
# xq_code： BUSINESS_COMMUNITY-141450077282 :全部数据点： 120 个：可用数据点： 89 个：异常数据点: 31 个
# xq_code： BUSINESS_COMMUNITY-141450077282 计算簇个数为 0 个，稍后计算！
# 当前计算第 179 个小区
# xq_code： BUSINESS_COMMUNITY-141450077283 :全部数据点： 47 个：可用数据点： 41 个：异常数据点: 6 个
# xq_code： BUSINESS_COMMUNITY-141450077283 小区范围大小，重新计算
# 当前计算第 180 个小区
# xq_code： BUSINESS_COMMUNITY-141450077306 :全部数据点： 81 个：可用数据点： 56 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141450077306 计算簇个数为 0 个，稍后计算！
# 当前计算第 181 个小区
# xq_code： BUSINESS_COMMUNITY-141450077362 :全部数据点： 108 个：可用数据点： 85 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450077362 计算簇个数为 0 个，稍后计算！
# 当前计算第 182 个小区
# xq_code： BUSINESS_COMMUNITY-141450077372 :全部数据点： 58 个：可用数据点： 37 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450077372 小区范围大小，重新计算
# 当前计算第 183 个小区
# xq_code： BUSINESS_COMMUNITY-141450077377 :全部数据点： 75 个：可用数据点： 57 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450077377 计算簇个数为 0 个，稍后计算！
# 当前计算第 184 个小区
# xq_code： BUSINESS_COMMUNITY-141450077389 :全部数据点： 85 个：可用数据点： 31 个：异常数据点: 54 个
# xq_code： BUSINESS_COMMUNITY-141450077389 计算簇个数为 0 个，稍后计算！
# 当前计算第 185 个小区
# xq_code： BUSINESS_COMMUNITY-141450077398 :全部数据点： 86 个：可用数据点： 60 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-141450077398 计算簇个数为 0 个，稍后计算！
# 当前计算第 186 个小区
# xq_code： BUSINESS_COMMUNITY-141450077929 :全部数据点： 191 个：可用数据点： 114 个：异常数据点: 77 个
# xq_code： BUSINESS_COMMUNITY-141450077929 计算簇个数为 0 个，稍后计算！
# 当前计算第 187 个小区
# xq_code： BUSINESS_COMMUNITY-141450077930 :全部数据点： 79 个：可用数据点： 61 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450077930 小区范围大小，重新计算
# 当前计算第 188 个小区
# xq_code： BUSINESS_COMMUNITY-141450077932 :全部数据点： 32 个：可用数据点： 27 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450077932 小区范围大小，重新计算
# 当前计算第 189 个小区
# xq_code： BUSINESS_COMMUNITY-141450077936 :全部数据点： 78 个：可用数据点： 49 个：异常数据点: 29 个
# 当前计算第 190 个小区
# xq_code： BUSINESS_COMMUNITY-141450077940 :全部数据点： 76 个：可用数据点： 62 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141450077940 计算簇个数为 0 个，稍后计算！
# 当前计算第 191 个小区
# xq_code： BUSINESS_COMMUNITY-141450077946 :全部数据点： 11 个：可用数据点： 7 个：异常数据点: 4 个
# xq_code： BUSINESS_COMMUNITY-141450077946 小区范围大小，重新计算
# 当前计算第 192 个小区
# xq_code： BUSINESS_COMMUNITY-141450077965 :全部数据点： 124 个：可用数据点： 94 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-141450077965 计算簇个数为 0 个，稍后计算！
# 当前计算第 193 个小区
# xq_code： BUSINESS_COMMUNITY-141450077969 :全部数据点： 47 个：可用数据点： 34 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450077969 计算簇个数为 0 个，稍后计算！
# 当前计算第 194 个小区
# xq_code： BUSINESS_COMMUNITY-141450078103 :全部数据点： 17 个：可用数据点： 15 个：异常数据点: 2 个
# xq_code： BUSINESS_COMMUNITY-141450078103 小区范围大小，重新计算
# 当前计算第 195 个小区
# xq_code： BUSINESS_COMMUNITY-141450078107 :全部数据点： 32 个：可用数据点： 25 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450078107 小区范围大小，重新计算
# 当前计算第 196 个小区
# xq_code： BUSINESS_COMMUNITY-141450078139 :全部数据点： 114 个：可用数据点： 70 个：异常数据点: 44 个
# xq_code： BUSINESS_COMMUNITY-141450078139 计算簇个数为 0 个，稍后计算！
# 当前计算第 197 个小区
# xq_code： BUSINESS_COMMUNITY-141450855210 :全部数据点： 39 个：可用数据点： 27 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450855210 计算簇个数为 0 个，稍后计算！
# 当前计算第 198 个小区
# xq_code： BUSINESS_COMMUNITY-141450855289 :全部数据点： 237 个：可用数据点： 179 个：异常数据点: 58 个
# xq_code： BUSINESS_COMMUNITY-141450855289 计算簇个数为 0 个，稍后计算！
# 当前计算第 199 个小区
# xq_code： BUSINESS_COMMUNITY-141450855292 :全部数据点： 129 个：可用数据点： 97 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450855292 计算簇个数为 0 个，稍后计算！
# 当前计算第 200 个小区
# xq_code： BUSINESS_COMMUNITY-141450855316 :全部数据点： 105 个：可用数据点： 72 个：异常数据点: 33 个
# xq_code： BUSINESS_COMMUNITY-141450855316 小区范围大小，重新计算
# 当前计算第 201 个小区
# xq_code： BUSINESS_COMMUNITY-141450855331 :全部数据点： 108 个：可用数据点： 73 个：异常数据点: 35 个
# xq_code： BUSINESS_COMMUNITY-141450855331 计算簇个数为 0 个，稍后计算！
# 当前计算第 202 个小区
# xq_code： BUSINESS_COMMUNITY-141450856978 :全部数据点： 61 个：可用数据点： 43 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450856978 小区范围大小，重新计算
# 当前计算第 203 个小区
# xq_code： BUSINESS_COMMUNITY-141450856979 :全部数据点： 17 个：可用数据点： 14 个：异常数据点: 3 个
# xq_code： BUSINESS_COMMUNITY-141450856979 计算簇个数为 0 个，稍后计算！
# 当前计算第 204 个小区
# xq_code： BUSINESS_COMMUNITY-141450856990 :全部数据点： 88 个：可用数据点： 58 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-141450856990 小区范围大小，重新计算
# 当前计算第 205 个小区
# xq_code： BUSINESS_COMMUNITY-141450857006 :全部数据点： 145 个：可用数据点： 102 个：异常数据点: 43 个
# xq_code： BUSINESS_COMMUNITY-141450857006 计算簇个数为 0 个，稍后计算！
# 当前计算第 206 个小区
# xq_code： BUSINESS_COMMUNITY-141450857009 :全部数据点： 58 个：可用数据点： 42 个：异常数据点: 16 个
# 当前计算第 207 个小区
# xq_code： BUSINESS_COMMUNITY-141450857023 :全部数据点： 38 个：可用数据点： 28 个：异常数据点: 10 个
# 当前计算第 208 个小区
# xq_code： BUSINESS_COMMUNITY-141450857072 :全部数据点： 91 个：可用数据点： 68 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141450857072 计算簇个数为 0 个，稍后计算！
# 当前计算第 209 个小区
# xq_code： BUSINESS_COMMUNITY-141450857097 :全部数据点： 107 个：可用数据点： 91 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450857097 小区范围大小，重新计算
# 当前计算第 210 个小区
# xq_code： BUSINESS_COMMUNITY-141450857110 :全部数据点： 35 个：可用数据点： 27 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450857110 计算簇个数为 0 个，稍后计算！
# 当前计算第 211 个小区
# xq_code： BUSINESS_COMMUNITY-141450857130 :全部数据点： 121 个：可用数据点： 82 个：异常数据点: 39 个
# xq_code： BUSINESS_COMMUNITY-141450857130 小区范围大小，重新计算
# 当前计算第 212 个小区
# xq_code： BUSINESS_COMMUNITY-141450857152 :全部数据点： 36 个：可用数据点： 26 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-141450857152 计算簇个数为 0 个，稍后计算！
# 当前计算第 213 个小区
# xq_code： BUSINESS_COMMUNITY-141450857160 :全部数据点： 90 个：可用数据点： 61 个：异常数据点: 29 个
# xq_code： BUSINESS_COMMUNITY-141450857160 计算簇个数为 0 个，稍后计算！
# 当前计算第 214 个小区
# xq_code： BUSINESS_COMMUNITY-141450857186 :全部数据点： 95 个：可用数据点： 73 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450857186 计算簇个数为 0 个，稍后计算！
# 当前计算第 215 个小区
# xq_code： BUSINESS_COMMUNITY-141450857215 :全部数据点： 41 个：可用数据点： 30 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450857215 计算簇个数为 0 个，稍后计算！
# 当前计算第 216 个小区
# xq_code： BUSINESS_COMMUNITY-141450857343 :全部数据点： 100 个：可用数据点： 81 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450857343 小区范围大小，重新计算
# 当前计算第 217 个小区
# xq_code： BUSINESS_COMMUNITY-141450857344 :全部数据点： 261 个：可用数据点： 198 个：异常数据点: 63 个
# xq_code： BUSINESS_COMMUNITY-141450857344 计算簇个数为 0 个，稍后计算！
# 当前计算第 218 个小区
# xq_code： BUSINESS_COMMUNITY-141450857379 :全部数据点： 454 个：可用数据点： 334 个：异常数据点: 120 个
# 当前计算第 219 个小区
# xq_code： BUSINESS_COMMUNITY-141450857390 :全部数据点： 53 个：可用数据点： 48 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450857390 计算簇个数为 0 个，稍后计算！
# 当前计算第 220 个小区
# xq_code： BUSINESS_COMMUNITY-141450857423 :全部数据点： 59 个：可用数据点： 47 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450857423 小区范围大小，重新计算
# 当前计算第 221 个小区
# xq_code： BUSINESS_COMMUNITY-141450857462 :全部数据点： 58 个：可用数据点： 37 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450857462 计算簇个数为 0 个，稍后计算！
# 当前计算第 222 个小区
# xq_code： BUSINESS_COMMUNITY-141450857484 :全部数据点： 117 个：可用数据点： 88 个：异常数据点: 29 个
# xq_code： BUSINESS_COMMUNITY-141450857484 计算簇个数为 0 个，稍后计算！
# 当前计算第 223 个小区
# xq_code： BUSINESS_COMMUNITY-141450857485 :全部数据点： 83 个：可用数据点： 61 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450857485 小区范围大小，重新计算
# 当前计算第 224 个小区
# xq_code： BUSINESS_COMMUNITY-141450857489 :全部数据点： 83 个：可用数据点： 61 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450857489 计算簇个数为 0 个，稍后计算！
# 当前计算第 225 个小区
# xq_code： BUSINESS_COMMUNITY-141450857493 :全部数据点： 286 个：可用数据点： 220 个：异常数据点: 66 个
# xq_code： BUSINESS_COMMUNITY-141450857493 计算簇个数为 0 个，稍后计算！
# 当前计算第 226 个小区
# xq_code： BUSINESS_COMMUNITY-141450857503 :全部数据点： 69 个：可用数据点： 52 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450857503 计算簇个数为 0 个，稍后计算！
# 当前计算第 227 个小区
# xq_code： BUSINESS_COMMUNITY-141450857550 :全部数据点： 25 个：可用数据点： 20 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141450857550 计算簇个数为 0 个，稍后计算！
# 当前计算第 228 个小区
# xq_code： BUSINESS_COMMUNITY-141450857585 :全部数据点： 186 个：可用数据点： 137 个：异常数据点: 49 个
# xq_code： BUSINESS_COMMUNITY-141450857585 小区范围大小，重新计算
# 当前计算第 229 个小区
# xq_code： BUSINESS_COMMUNITY-141450857591 :全部数据点： 60 个：可用数据点： 43 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450857591 小区范围大小，重新计算
# 当前计算第 230 个小区
# xq_code： BUSINESS_COMMUNITY-141450857607 :全部数据点： 7 个：可用数据点： 0 个：异常数据点: 7 个
# 当前计算第 231 个小区
# xq_code： BUSINESS_COMMUNITY-141450857635 :全部数据点： 129 个：可用数据点： 96 个：异常数据点: 33 个
# xq_code： BUSINESS_COMMUNITY-141450857635 计算簇个数为 0 个，稍后计算！
# 当前计算第 232 个小区
# xq_code： BUSINESS_COMMUNITY-141450857639 :全部数据点： 150 个：可用数据点： 108 个：异常数据点: 42 个
# xq_code： BUSINESS_COMMUNITY-141450857639 小区范围大小，重新计算
# 当前计算第 233 个小区
# xq_code： BUSINESS_COMMUNITY-141450857645 :全部数据点： 101 个：可用数据点： 70 个：异常数据点: 31 个
# xq_code： BUSINESS_COMMUNITY-141450857645 小区范围大小，重新计算
# 当前计算第 234 个小区
# xq_code： BUSINESS_COMMUNITY-141450857647 :全部数据点： 121 个：可用数据点： 87 个：异常数据点: 34 个
# xq_code： BUSINESS_COMMUNITY-141450857647 小区范围大小，重新计算
# 当前计算第 235 个小区
# xq_code： BUSINESS_COMMUNITY-141450857690 :全部数据点： 64 个：可用数据点： 43 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450857690 计算簇个数为 0 个，稍后计算！
# 当前计算第 236 个小区
# xq_code： BUSINESS_COMMUNITY-141450857694 :全部数据点： 46 个：可用数据点： 34 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450857694 计算簇个数为 0 个，稍后计算！
# 当前计算第 237 个小区
# xq_code： BUSINESS_COMMUNITY-141450857712 :全部数据点： 33 个：可用数据点： 23 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-141450857712 计算簇个数为 0 个，稍后计算！
# 当前计算第 238 个小区
# xq_code： BUSINESS_COMMUNITY-141450857728 :全部数据点： 85 个：可用数据点： 49 个：异常数据点: 36 个
# xq_code： BUSINESS_COMMUNITY-141450857728 小区范围大小，重新计算
# 当前计算第 239 个小区
# xq_code： BUSINESS_COMMUNITY-141450857740 :全部数据点： 61 个：可用数据点： 42 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450857740 计算簇个数为 0 个，稍后计算！
# 当前计算第 240 个小区
# xq_code： BUSINESS_COMMUNITY-141450857841 :全部数据点： 201 个：可用数据点： 148 个：异常数据点: 53 个
# xq_code： BUSINESS_COMMUNITY-141450857841 计算簇个数为 0 个，稍后计算！
# 当前计算第 241 个小区
# xq_code： BUSINESS_COMMUNITY-141450857905 :全部数据点： 62 个：可用数据点： 41 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450857905 计算簇个数为 0 个，稍后计算！
# 当前计算第 242 个小区
# xq_code： BUSINESS_COMMUNITY-141450857911 :全部数据点： 68 个：可用数据点： 50 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450857911 小区范围大小，重新计算
# 当前计算第 243 个小区
# xq_code： BUSINESS_COMMUNITY-141450857999 :全部数据点： 40 个：可用数据点： 29 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450857999 小区范围大小，重新计算
# 当前计算第 244 个小区
# xq_code： BUSINESS_COMMUNITY-141450858004 :全部数据点： 78 个：可用数据点： 62 个：异常数据点: 16 个
# xq_code： BUSINESS_COMMUNITY-141450858004 计算簇个数为 0 个，稍后计算！
# 当前计算第 245 个小区
# xq_code： BUSINESS_COMMUNITY-141450858032 :全部数据点： 66 个：可用数据点： 55 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450858032 计算簇个数为 0 个，稍后计算！
# 当前计算第 246 个小区
# xq_code： BUSINESS_COMMUNITY-141450858074 :全部数据点： 162 个：可用数据点： 117 个：异常数据点: 45 个
# xq_code： BUSINESS_COMMUNITY-141450858074 计算簇个数为 0 个，稍后计算！
# 当前计算第 247 个小区
# xq_code： BUSINESS_COMMUNITY-141450858354 :全部数据点： 669 个：可用数据点： 497 个：异常数据点: 172 个
# xq_code： BUSINESS_COMMUNITY-141450858354 计算簇个数为 0 个，稍后计算！
# 当前计算第 248 个小区
# xq_code： BUSINESS_COMMUNITY-141450858489 :全部数据点： 128 个：可用数据点： 97 个：异常数据点: 31 个
# 当前计算第 249 个小区
# xq_code： BUSINESS_COMMUNITY-141450858497 :全部数据点： 75 个：可用数据点： 44 个：异常数据点: 31 个
# xq_code： BUSINESS_COMMUNITY-141450858497 计算簇个数为 0 个，稍后计算！
# 当前计算第 250 个小区
# xq_code： BUSINESS_COMMUNITY-141450858501 :全部数据点： 87 个：可用数据点： 50 个：异常数据点: 37 个
# xq_code： BUSINESS_COMMUNITY-141450858501 计算簇个数为 0 个，稍后计算！
# 当前计算第 251 个小区
# xq_code： BUSINESS_COMMUNITY-141450858539 :全部数据点： 76 个：可用数据点： 65 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450858539 计算簇个数为 0 个，稍后计算！
# 当前计算第 252 个小区
# xq_code： BUSINESS_COMMUNITY-141450858540 :全部数据点： 64 个：可用数据点： 43 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141450858540 计算簇个数为 0 个，稍后计算！
# 当前计算第 253 个小区
# xq_code： BUSINESS_COMMUNITY-141450858543 :全部数据点： 102 个：可用数据点： 85 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141450858543 计算簇个数为 0 个，稍后计算！
# 当前计算第 254 个小区
# xq_code： BUSINESS_COMMUNITY-141450858561 :全部数据点： 91 个：可用数据点： 59 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141450858561 计算簇个数为 0 个，稍后计算！
# 当前计算第 255 个小区
# xq_code： BUSINESS_COMMUNITY-141450858606 :全部数据点： 32 个：可用数据点： 20 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141450858606 计算簇个数为 0 个，稍后计算！
# 当前计算第 256 个小区
# xq_code： BUSINESS_COMMUNITY-141450858608 :全部数据点： 25 个：可用数据点： 12 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450858608 计算簇个数为 0 个，稍后计算！
# 当前计算第 257 个小区
# xq_code： BUSINESS_COMMUNITY-141450858629 :全部数据点： 119 个：可用数据点： 95 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450858629 计算簇个数为 0 个，稍后计算！
# 当前计算第 258 个小区
# xq_code： BUSINESS_COMMUNITY-141450858630 :全部数据点： 36 个：可用数据点： 29 个：异常数据点: 7 个
# xq_code： BUSINESS_COMMUNITY-141450858630 小区范围大小，重新计算
# 当前计算第 259 个小区
# xq_code： BUSINESS_COMMUNITY-141450858632 :全部数据点： 68 个：可用数据点： 55 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141450858632 计算簇个数为 0 个，稍后计算！
# 当前计算第 260 个小区
# xq_code： BUSINESS_COMMUNITY-141450858636 :全部数据点： 70 个：可用数据点： 59 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450858636 小区范围大小，重新计算
# 当前计算第 261 个小区
# xq_code： BUSINESS_COMMUNITY-141450858641 :全部数据点： 78 个：可用数据点： 60 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450858641 计算簇个数为 0 个，稍后计算！
# 当前计算第 262 个小区
# xq_code： BUSINESS_COMMUNITY-141450858643 :全部数据点： 221 个：可用数据点： 175 个：异常数据点: 46 个
# xq_code： BUSINESS_COMMUNITY-141450858643 计算簇个数为 0 个，稍后计算！
# 当前计算第 263 个小区
# xq_code： BUSINESS_COMMUNITY-141450858679 :全部数据点： 110 个：可用数据点： 88 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141450858679 小区范围大小，重新计算
# 当前计算第 264 个小区
# xq_code： BUSINESS_COMMUNITY-141450858681 :全部数据点： 72 个：可用数据点： 53 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141450858681 计算簇个数为 0 个，稍后计算！
# 当前计算第 265 个小区
# xq_code： BUSINESS_COMMUNITY-141450858685 :全部数据点： 94 个：可用数据点： 74 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450858685 计算簇个数为 0 个，稍后计算！
# 当前计算第 266 个小区
# xq_code： BUSINESS_COMMUNITY-141450858699 :全部数据点： 138 个：可用数据点： 95 个：异常数据点: 43 个
# xq_code： BUSINESS_COMMUNITY-141450858699 计算簇个数为 0 个，稍后计算！
# 当前计算第 267 个小区
# xq_code： BUSINESS_COMMUNITY-141450858762 :全部数据点： 135 个：可用数据点： 95 个：异常数据点: 40 个
# xq_code： BUSINESS_COMMUNITY-141450858762 计算簇个数为 0 个，稍后计算！
# 当前计算第 268 个小区
# xq_code： BUSINESS_COMMUNITY-141450858764 :全部数据点： 44 个：可用数据点： 26 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450858764 计算簇个数为 0 个，稍后计算！
# 当前计算第 269 个小区
# xq_code： BUSINESS_COMMUNITY-141450858822 :全部数据点： 91 个：可用数据点： 76 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141450858822 计算簇个数为 0 个，稍后计算！
# 当前计算第 270 个小区
# xq_code： BUSINESS_COMMUNITY-141450858880 :全部数据点： 113 个：可用数据点： 73 个：异常数据点: 40 个
# 当前计算第 271 个小区
# xq_code： BUSINESS_COMMUNITY-141450858881 :全部数据点： 61 个：可用数据点： 37 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450858881 小区范围大小，重新计算
# 当前计算第 272 个小区
# xq_code： BUSINESS_COMMUNITY-141450858964 :全部数据点： 155 个：可用数据点： 109 个：异常数据点: 46 个
# xq_code： BUSINESS_COMMUNITY-141450858964 计算簇个数为 0 个，稍后计算！
# 当前计算第 273 个小区
# xq_code： BUSINESS_COMMUNITY-141450858984 :全部数据点： 42 个：可用数据点： 34 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141450858984 计算簇个数为 0 个，稍后计算！
# 当前计算第 274 个小区
# xq_code： BUSINESS_COMMUNITY-141450859000 :全部数据点： 221 个：可用数据点： 171 个：异常数据点: 50 个
# 当前计算第 275 个小区
# xq_code： BUSINESS_COMMUNITY-141450859039 :全部数据点： 41 个：可用数据点： 36 个：异常数据点: 5 个
# 当前计算第 276 个小区
# xq_code： BUSINESS_COMMUNITY-141450859045 :全部数据点： 103 个：可用数据点： 72 个：异常数据点: 31 个
# xq_code： BUSINESS_COMMUNITY-141450859045 小区范围大小，重新计算
# 当前计算第 277 个小区
# xq_code： BUSINESS_COMMUNITY-141450859102 :全部数据点： 3 个：可用数据点： 2 个：异常数据点: 1 个
# xq_code： BUSINESS_COMMUNITY-141450859102 计算簇个数为 2 个，稍后计算！
# 当前计算第 278 个小区
# xq_code： BUSINESS_COMMUNITY-141450859106 :全部数据点： 64 个：可用数据点： 53 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141450859106 计算簇个数为 0 个，稍后计算！
# 当前计算第 279 个小区
# xq_code： BUSINESS_COMMUNITY-141450859116 :全部数据点： 464 个：可用数据点： 348 个：异常数据点: 116 个
# xq_code： BUSINESS_COMMUNITY-141450859116 计算簇个数为 0 个，稍后计算！
# 当前计算第 280 个小区
# xq_code： BUSINESS_COMMUNITY-141450859179 :全部数据点： 188 个：可用数据点： 140 个：异常数据点: 48 个
# xq_code： BUSINESS_COMMUNITY-141450859179 计算簇个数为 0 个，稍后计算！
# 当前计算第 281 个小区
# xq_code： BUSINESS_COMMUNITY-141450859211 :全部数据点： 103 个：可用数据点： 75 个：异常数据点: 28 个
# xq_code： BUSINESS_COMMUNITY-141450859211 计算簇个数为 0 个，稍后计算！
# 当前计算第 282 个小区
# xq_code： BUSINESS_COMMUNITY-141450859227 :全部数据点： 248 个：可用数据点： 158 个：异常数据点: 90 个
# xq_code： BUSINESS_COMMUNITY-141450859227 计算簇个数为 0 个，稍后计算！
# 当前计算第 283 个小区
# xq_code： BUSINESS_COMMUNITY-141450859266 :全部数据点： 88 个：可用数据点： 70 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141450859266 计算簇个数为 0 个，稍后计算！
# 当前计算第 284 个小区
# xq_code： BUSINESS_COMMUNITY-141450859308 :全部数据点： 66 个：可用数据点： 46 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141450859308 计算簇个数为 0 个，稍后计算！
# 当前计算第 285 个小区
# xq_code： BUSINESS_COMMUNITY-141450859332 :全部数据点： 147 个：可用数据点： 98 个：异常数据点: 49 个
# xq_code： BUSINESS_COMMUNITY-141450859332 计算簇个数为 0 个，稍后计算！
# 当前计算第 286 个小区
# xq_code： BUSINESS_COMMUNITY-141450859341 :全部数据点： 65 个：可用数据点： 41 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141450859341 计算簇个数为 0 个，稍后计算！
# 当前计算第 287 个小区
# xq_code： BUSINESS_COMMUNITY-141452975766 :全部数据点： 41 个：可用数据点： 32 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-141452975766 小区范围大小，重新计算
# 当前计算第 288 个小区
# xq_code： BUSINESS_COMMUNITY-141452975774 :全部数据点： 106 个：可用数据点： 77 个：异常数据点: 29 个
# 当前计算第 289 个小区
# xq_code： BUSINESS_COMMUNITY-141452975877 :全部数据点： 37 个：可用数据点： 33 个：异常数据点: 4 个
# xq_code： BUSINESS_COMMUNITY-141452975877 小区范围大小，重新计算
# 当前计算第 290 个小区
# xq_code： BUSINESS_COMMUNITY-141452975879 :全部数据点： 53 个：可用数据点： 41 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141452975879 计算簇个数为 0 个，稍后计算！
# 当前计算第 291 个小区
# xq_code： BUSINESS_COMMUNITY-141452975900 :全部数据点： 48 个：可用数据点： 43 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-141452975900 小区范围大小，重新计算
# 当前计算第 292 个小区
# xq_code： BUSINESS_COMMUNITY-141452975903 :全部数据点： 84 个：可用数据点： 63 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-141452975903 计算簇个数为 0 个，稍后计算！
# 当前计算第 293 个小区
# xq_code： BUSINESS_COMMUNITY-141452975927 :全部数据点： 80 个：可用数据点： 56 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-141452975927 小区范围大小，重新计算
# 当前计算第 294 个小区
# xq_code： BUSINESS_COMMUNITY-141452975935 :全部数据点： 103 个：可用数据点： 71 个：异常数据点: 32 个
# xq_code： BUSINESS_COMMUNITY-141452975935 小区范围大小，重新计算
# 当前计算第 295 个小区
# xq_code： BUSINESS_COMMUNITY-141452975938 :全部数据点： 70 个：可用数据点： 53 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141452975938 小区范围大小，重新计算
# 当前计算第 296 个小区
# xq_code： BUSINESS_COMMUNITY-141452975993 :全部数据点： 73 个：可用数据点： 51 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141452975993 计算簇个数为 0 个，稍后计算！
# 当前计算第 297 个小区
# xq_code： BUSINESS_COMMUNITY-141452975995 :全部数据点： 64 个：可用数据点： 49 个：异常数据点: 15 个
# xq_code： BUSINESS_COMMUNITY-141452975995 计算簇个数为 0 个，稍后计算！
# 当前计算第 298 个小区
# xq_code： BUSINESS_COMMUNITY-141452975996 :全部数据点： 64 个：可用数据点： 52 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141452975996 计算簇个数为 0 个，稍后计算！
# 当前计算第 299 个小区
# xq_code： BUSINESS_COMMUNITY-141452976010 :全部数据点： 98 个：可用数据点： 80 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141452976010 小区范围大小，重新计算
# 当前计算第 300 个小区
# xq_code： BUSINESS_COMMUNITY-141452976403 :全部数据点： 86 个：可用数据点： 61 个：异常数据点: 25 个
# 当前计算第 301 个小区
# xq_code： BUSINESS_COMMUNITY-141452976408 :全部数据点： 41 个：可用数据点： 24 个：异常数据点: 17 个
# xq_code： BUSINESS_COMMUNITY-141452976408 小区范围大小，重新计算
# 当前计算第 302 个小区
# xq_code： BUSINESS_COMMUNITY-141452976473 :全部数据点： 27 个：可用数据点： 19 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141452976473 小区范围大小，重新计算
# 当前计算第 303 个小区
# xq_code： BUSINESS_COMMUNITY-141452976553 :全部数据点： 67 个：可用数据点： 48 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141452976553 小区范围大小，重新计算
# 当前计算第 304 个小区
# xq_code： BUSINESS_COMMUNITY-141452976557 :全部数据点： 145 个：可用数据点： 119 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-141452976557 小区范围大小，重新计算
# 当前计算第 305 个小区
# xq_code： BUSINESS_COMMUNITY-141452976664 :全部数据点： 93 个：可用数据点： 79 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141452976664 计算簇个数为 0 个，稍后计算！
# 当前计算第 306 个小区
# xq_code： BUSINESS_COMMUNITY-141452976668 :全部数据点： 58 个：可用数据点： 44 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141452976668 小区范围大小，重新计算
# 当前计算第 307 个小区
# xq_code： BUSINESS_COMMUNITY-141452976689 :全部数据点： 48 个：可用数据点： 40 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-141452976689 计算簇个数为 0 个，稍后计算！
# 当前计算第 308 个小区
# xq_code： BUSINESS_COMMUNITY-141452976751 :全部数据点： 66 个：可用数据点： 39 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-141452976751 小区范围大小，重新计算
# 当前计算第 309 个小区
# xq_code： BUSINESS_COMMUNITY-141452976850 :全部数据点： 87 个：可用数据点： 68 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141452976850 计算簇个数为 0 个，稍后计算！
# 当前计算第 310 个小区
# xq_code： BUSINESS_COMMUNITY-141452976860 :全部数据点： 107 个：可用数据点： 82 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-141452976860 小区范围大小，重新计算
# 当前计算第 311 个小区
# xq_code： BUSINESS_COMMUNITY-141452976886 :全部数据点： 188 个：可用数据点： 138 个：异常数据点: 50 个
# xq_code： BUSINESS_COMMUNITY-141452976886 计算簇个数为 0 个，稍后计算！
# 当前计算第 312 个小区
# xq_code： BUSINESS_COMMUNITY-141452977003 :全部数据点： 74 个：可用数据点： 55 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-141452977003 小区范围大小，重新计算
# 当前计算第 313 个小区
# xq_code： BUSINESS_COMMUNITY-141452977058 :全部数据点： 220 个：可用数据点： 173 个：异常数据点: 47 个
# xq_code： BUSINESS_COMMUNITY-141452977058 计算簇个数为 0 个，稍后计算！
# 当前计算第 314 个小区
# xq_code： BUSINESS_COMMUNITY-141452977089 :全部数据点： 195 个：可用数据点： 155 个：异常数据点: 40 个
# xq_code： BUSINESS_COMMUNITY-141452977089 计算簇个数为 0 个，稍后计算！
# 当前计算第 315 个小区
# xq_code： BUSINESS_COMMUNITY-141452977189 :全部数据点： 71 个：可用数据点： 48 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-141452977189 小区范围大小，重新计算
# 当前计算第 316 个小区
# xq_code： BUSINESS_COMMUNITY-141452977197 :全部数据点： 337 个：可用数据点： 277 个：异常数据点: 60 个
# xq_code： BUSINESS_COMMUNITY-141452977197 小区范围大小，重新计算
# 当前计算第 317 个小区
# xq_code： BUSINESS_COMMUNITY-141452977216 :全部数据点： 36 个：可用数据点： 25 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-141452977216 小区范围大小，重新计算
# 当前计算第 318 个小区
# xq_code： BUSINESS_COMMUNITY-141452977269 :全部数据点： 189 个：可用数据点： 139 个：异常数据点: 50 个
# xq_code： BUSINESS_COMMUNITY-141452977269 计算簇个数为 0 个，稍后计算！
# 当前计算第 319 个小区
# xq_code： BUSINESS_COMMUNITY-141452977327 :全部数据点： 29 个：可用数据点： 16 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-141452977327 计算簇个数为 0 个，稍后计算！
# 当前计算第 320 个小区
# xq_code： BUSINESS_COMMUNITY-141452977338 :全部数据点： 91 个：可用数据点： 73 个：异常数据点: 18 个
# xq_code： BUSINESS_COMMUNITY-141452977338 小区范围大小，重新计算
# 当前计算第 321 个小区
# xq_code： BUSINESS_COMMUNITY-141452977352 :全部数据点： 77 个：可用数据点： 63 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141452977352 小区范围大小，重新计算
# 当前计算第 322 个小区
# xq_code： BUSINESS_COMMUNITY-141452977370 :全部数据点： 87 个：可用数据点： 65 个：异常数据点: 22 个
# xq_code： BUSINESS_COMMUNITY-141452977370 小区范围大小，重新计算
# 当前计算第 323 个小区
# xq_code： BUSINESS_COMMUNITY-141452977378 :全部数据点： 179 个：可用数据点： 117 个：异常数据点: 62 个
# xq_code： BUSINESS_COMMUNITY-141452977378 小区范围大小，重新计算
# 当前计算第 324 个小区
# xq_code： BUSINESS_COMMUNITY-141452977407 :全部数据点： 132 个：可用数据点： 95 个：异常数据点: 37 个
# xq_code： BUSINESS_COMMUNITY-141452977407 计算簇个数为 0 个，稍后计算！
# 当前计算第 325 个小区
# xq_code： BUSINESS_COMMUNITY-141452977420 :全部数据点： 364 个：可用数据点： 276 个：异常数据点: 88 个
# xq_code： BUSINESS_COMMUNITY-141452977420 计算簇个数为 0 个，稍后计算！
# 当前计算第 326 个小区
# xq_code： BUSINESS_COMMUNITY-141452977439 :全部数据点： 47 个：可用数据点： 35 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-141452977439 计算簇个数为 0 个，稍后计算！
# 当前计算第 327 个小区
# xq_code： BUSINESS_COMMUNITY-141452977490 :全部数据点： 75 个：可用数据点： 55 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-141452977490 小区范围大小，重新计算
# 当前计算第 328 个小区
# xq_code： BUSINESS_COMMUNITY-141452977501 :全部数据点： 268 个：可用数据点： 200 个：异常数据点: 68 个
# xq_code： BUSINESS_COMMUNITY-141452977501 计算簇个数为 0 个，稍后计算！
# 当前计算第 329 个小区
# xq_code： BUSINESS_COMMUNITY-141452977607 :全部数据点： 121 个：可用数据点： 93 个：异常数据点: 28 个
# 当前计算第 330 个小区
# xq_code： BUSINESS_COMMUNITY-141452977668 :全部数据点： 69 个：可用数据点： 55 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-141452977668 小区范围大小，重新计算
# 当前计算第 331 个小区
# xq_code： BUSINESS_COMMUNITY-141452977674 :全部数据点： 118 个：可用数据点： 91 个：异常数据点: 27 个
# 当前计算第 332 个小区
# xq_code： BUSINESS_COMMUNITY-141452977681 :全部数据点： 164 个：可用数据点： 122 个：异常数据点: 42 个
# xq_code： BUSINESS_COMMUNITY-141452977681 计算簇个数为 0 个，稍后计算！
# 当前计算第 333 个小区
# xq_code： BUSINESS_COMMUNITY-141452977730 :全部数据点： 103 个：可用数据点： 76 个：异常数据点: 27 个
# ...
# 当前计算第 187 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0164cb796cd423be :全部数据点： 35 个：可用数据点： 1 个：异常数据点: 34 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0164cb796cd423be 小区范围大小，重新计算
# 当前计算第 188 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0164ea4f7c1d2e58 :全部数据点： 41 个：可用数据点： 29 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0164ea4f7c1d2e58 小区范围大小，重新计算
# 当前计算第 189 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0164ef1e2c992fce :全部数据点： 82 个：可用数据点： 57 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0164ef1e2c992fce 小区范围大小，重新计算
# 当前计算第 190 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016556e5687f56a4 :全部数据点： 51 个：可用数据点： 30 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016556e5687f56a4 小区范围大小，重新计算
# 当前计算第 191 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016560c68cee5b9e :全部数据点： 27 个：可用数据点： 22 个：异常数据点: 5 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016560c68cee5b9e 小区范围大小，重新计算
# 当前计算第 192 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016565cf09635f06 :全部数据点： 61 个：可用数据点： 41 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016565cf09635f06 小区范围大小，重新计算
# 当前计算第 193 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016565fae3915f6e :全部数据点： 91 个：可用数据点： 21 个：异常数据点: 70 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016565fae3915f6e 小区范围大小，重新计算
# 当前计算第 194 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016578d988ef6790 :全部数据点： 70 个：可用数据点： 49 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb016578d988ef6790 小区范围大小，重新计算
# 当前计算第 195 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb01658d69f8117774 :全部数据点： 64 个：可用数据点： 45 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb01658d69f8117774 计算簇个数为 2 个，稍后计算！
# 当前计算第 196 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb01658ecddb8c78b8 :全部数据点： 45 个：可用数据点： 32 个：异常数据点: 13 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb01658ecddb8c78b8 小区范围大小，重新计算
# 当前计算第 197 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0165a3bac3807f98 :全部数据点： 39 个：可用数据点： 31 个：异常数据点: 8 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0165a3bac3807f98 计算簇个数为 2 个，稍后计算！
# 当前计算第 198 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0165a739e31a00e0 :全部数据点： 41 个：可用数据点： 14 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0165a739e31a00e0 小区范围大小，重新计算
# 当前计算第 199 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0165addfe3b3030a :全部数据点： 51 个：可用数据点： 28 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0165addfe3b3030a 计算簇个数为 2 个，稍后计算！
# 当前计算第 200 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0165b3923182068e :全部数据点： 178 个：可用数据点： 129 个：异常数据点: 49 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d10646805eb0165b3923182068e 计算簇个数为 2 个，稍后计算！
# 当前计算第 201 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165d23d2c6f0b18 :全部数据点： 50 个：可用数据点： 2 个：异常数据点: 48 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165d23d2c6f0b18 计算簇个数为 2 个，稍后计算！
# 当前计算第 202 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165d71296df0c08 :全部数据点： 62 个：可用数据点： 6 个：异常数据点: 56 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165d71296df0c08 计算簇个数为 2 个，稍后计算！
# 当前计算第 203 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165e67996440fa0 :全部数据点： 71 个：可用数据点： 48 个：异常数据点: 23 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165e67996440fa0 小区范围大小，重新计算
# 当前计算第 204 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165f49f3d0416d0 :全部数据点： 47 个：可用数据点： 23 个：异常数据点: 24 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165f49f3d0416d0 小区范围大小，重新计算
# 当前计算第 205 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165ff7aafce1c68 :全部数据点： 46 个：可用数据点： 35 个：异常数据点: 11 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0165ff7aafce1c68 计算簇个数为 2 个，稍后计算！
# 当前计算第 206 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01660045bf141ec0 :全部数据点： 56 个：可用数据点： 30 个：异常数据点: 26 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01660045bf141ec0 小区范围大小，重新计算
# 当前计算第 207 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016605d7918e1fb0 :全部数据点： 102 个：可用数据点： 77 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016605d7918e1fb0 小区范围大小，重新计算
# 当前计算第 208 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01660e30ba4e2128 :全部数据点： 39 个：可用数据点： 37 个：异常数据点: 2 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01660e30ba4e2128 小区范围大小，重新计算
# 当前计算第 209 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016614eb7b9428b8 :全部数据点： 52 个：可用数据点： 32 个：异常数据点: 20 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016614eb7b9428b8 小区范围大小，重新计算
# 当前计算第 210 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166195e5c332c78 :全部数据点： 27 个：可用数据点： 18 个：异常数据点: 9 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166195e5c332c78 计算簇个数为 2 个，稍后计算！
# 当前计算第 211 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01661997d9c92ca8 :全部数据点： 61 个：可用数据点： 36 个：异常数据点: 25 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01661997d9c92ca8 计算簇个数为 2 个，稍后计算！
# 当前计算第 212 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01661fd5e0d33228 :全部数据点： 93 个：可用数据点： 51 个：异常数据点: 42 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01661fd5e0d33228 小区范围大小，重新计算
# 当前计算第 213 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016632493b073b78 :全部数据点： 14 个：可用数据点： 8 个：异常数据点: 6 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016632493b073b78 小区范围大小，重新计算
# 当前计算第 214 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166566a88f94180 :全部数据点： 54 个：可用数据点： 27 个：异常数据点: 27 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166566a88f94180 小区范围大小，重新计算
# 当前计算第 215 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01665b7bca2442e8 :全部数据点： 47 个：可用数据点： 33 个：异常数据点: 14 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01665b7bca2442e8 小区范围大小，重新计算
# 当前计算第 216 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01669f6709cd5b70 :全部数据点： 105 个：可用数据点： 40 个：异常数据点: 65 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01669f6709cd5b70 计算簇个数为 0 个，稍后计算！
# 当前计算第 217 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166a96aece961a8 :全部数据点： 40 个：可用数据点： 21 个：异常数据点: 19 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166a96aece961a8 计算簇个数为 2 个，稍后计算！
# 当前计算第 218 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166b5ee24c06980 :全部数据点： 14 个：可用数据点： 13 个：异常数据点: 1 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166b5ee24c06980 小区范围大小，重新计算
# 当前计算第 219 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166bea42be26c30 :全部数据点： 30 个：可用数据点： 24 个：异常数据点: 6 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166bea42be26c30 小区范围大小，重新计算
# 当前计算第 220 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166bf6bbf026d40 :全部数据点： 82 个：可用数据点： 11 个：异常数据点: 71 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166bf6bbf026d40 小区范围大小，重新计算
# 当前计算第 221 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166cce2fff57478 :全部数据点： 86 个：可用数据点： 53 个：异常数据点: 33 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166cce2fff57478 小区范围大小，重新计算
# 当前计算第 222 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166d466abff7820 :全部数据点： 88 个：可用数据点： 43 个：异常数据点: 45 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0166d466abff7820 小区范围大小，重新计算
# 当前计算第 223 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167444022b82350 :全部数据点： 36 个：可用数据点： 26 个：异常数据点: 10 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167444022b82350 小区范围大小，重新计算
# 当前计算第 224 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01675f01c40c30f0 :全部数据点： 62 个：可用数据点： 15 个：异常数据点: 47 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01675f01c40c30f0 小区范围大小，重新计算
# 当前计算第 225 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01677313415d3b68 :全部数据点： 31 个：可用数据点： 10 个：异常数据点: 21 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc01677313415d3b68 小区范围大小，重新计算
# 当前计算第 226 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016778524db53e20 :全部数据点： 116 个：可用数据点： 88 个：异常数据点: 28 个
# 当前计算第 227 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016796e4976b46f8 :全部数据点： 26 个：可用数据点： 22 个：异常数据点: 4 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc016796e4976b46f8 小区范围大小，重新计算
# 当前计算第 228 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167bf7e9b505640 :全部数据点： 23 个：可用数据点： 11 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167bf7e9b505640 计算簇个数为 2 个，稍后计算！
# 当前计算第 229 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167cff0a5076170 :全部数据点： 29 个：可用数据点： 18 个：异常数据点: 11 个
# 当前计算第 230 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e3f839c668f8 :全部数据点： 24 个：可用数据点： 12 个：异常数据点: 12 个
# xq_code： BUSINESS_COMMUNITY-8a9e2d1065c3e6dc0167e3f839c668f8 小区范围大小，重新计算
# 当前计算第 231 个小区
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b3641e04 :全部数据点： 70 个：可用数据点： 40 个：异常数据点: 30 个
# xq_code： BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b3641e04 小区范围大小，重新计算
# otherdf.shape (12726, 4)
#                                                  xq_code        user_id  \
# 0                        BUSINESS_COMMUNITY-141450071804  7100005463868
# 1                        BUSINESS_COMMUNITY-141450071804  7100005715619
# 2                        BUSINESS_COMMUNITY-141450071804  7100005789323
# 3                        BUSINESS_COMMUNITY-141450071804  7100005852246
# 4                        BUSINESS_COMMUNITY-141450071804  7104000489103
# 5                        BUSINESS_COMMUNITY-141450071804  7104010878897
# 6                        BUSINESS_COMMUNITY-141450071804  7104015194320
# 7                        BUSINESS_COMMUNITY-141450071804  7104018943563
# 8                        BUSINESS_COMMUNITY-141450071804  7104027261464
# 9                        BUSINESS_COMMUNITY-141450071804  7104040000148
# 10                       BUSINESS_COMMUNITY-141450071804  7104043406148
# 11                       BUSINESS_COMMUNITY-141450071804  7104046920957
# 12                       BUSINESS_COMMUNITY-141450071804  7104047044990
# 13                       BUSINESS_COMMUNITY-141450071804  7104403871030
# 14                       BUSINESS_COMMUNITY-141450071804  7104409792415
# 15                       BUSINESS_COMMUNITY-141450071804  7104425024303
# 16                       BUSINESS_COMMUNITY-141450071804  7104425408704
# 17                       BUSINESS_COMMUNITY-141450071804  7104435956486
# 18                       BUSINESS_COMMUNITY-141450071804  7104452620902
# 19                       BUSINESS_COMMUNITY-141450071804  7104466430374
# 20                       BUSINESS_COMMUNITY-141450071804  7104469249218
# 21                       BUSINESS_COMMUNITY-141450071804  7105007268542
# 22                       BUSINESS_COMMUNITY-141450071804  7105036602291
# 23                       BUSINESS_COMMUNITY-141450071804  7105040345787
# 24                       BUSINESS_COMMUNITY-141450071804  7105047497705
# 25                       BUSINESS_COMMUNITY-141450071804  7105176617495
# 26                       BUSINESS_COMMUNITY-141450071804  7105177641401
# 27                       BUSINESS_COMMUNITY-141450071804  7105177938917
# 28                       BUSINESS_COMMUNITY-141450071804  7105178104001
# 29                       BUSINESS_COMMUNITY-141450071804  7105179410469
# ...                                                  ...            ...
# 12696  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135193171989
# 12697  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135193365359
# 12698  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135194009067
# 12699  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135194043525
# 12700  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135195979955
# 12701  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135196877267
# 12702  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135198481991
# 12703  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135200081373
# 12704  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135201855581
# 12705  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135206693085
# 12706  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135206814879
# 12707  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135208494533
# 12708  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135209167781
# 12709  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135210824963
# 12710  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135211404523
# 12711  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135214408413
# 12712  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135217857057
# 12713  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135218729115
# 12714  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135221286691
# 12715  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135221641275
# 12716  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135224583509
# 12717  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135229827797
# 12718  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135232560993
# 12719  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135233512325
# 12720  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135236288827
# 12721  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135237222995
# 12722  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135247486835
# 12723  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135255707157
# 12724  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135265828889
# 12725  BUSINESS_COMMUNITY-8a9e74c95952ba540159bac1b36...  7135266229989
#
#        pre_night_longitude  pre_night_latitude
# 0               112.458680           32.083470
# 1               112.458680           32.083470
# 2               112.443336           32.088978
# 3               112.466111           32.090867
# 4               112.247520           32.086555
# 5               112.156850           32.056564
# 6               112.256134           32.078810
# 7               112.458680           32.083470
# 8               112.186720           32.081830
# 9               112.443336           32.088978
# 10              112.458680           32.083470
# 11              112.180810           32.081530
# 12              112.185165           32.083320
# 13              112.169850           32.079388
# 14              114.304230           30.471990
# 15              112.443336           32.088978
# 16              112.403790           32.092560
# 17              112.185165           32.083320
# 18              112.235050           32.095780
# 19              112.458680           32.083470
# 20              112.458680           32.083470
# 21              112.458680           32.083470
# 22              112.458680           32.083470
# 23              112.403790           32.092560
# 24              112.154440           32.058243
# 25              112.110940           32.044586
# 26              112.458680           32.083470
# 27              112.458680           32.083470
# 28              115.410480           30.193250
# 29              112.458680           32.083470
# ...                    ...                 ...
# 12696           115.441370           30.243702
# 12697           115.299510           30.921033
# 12698           115.299510           30.921033
# 12699           115.365210           29.933110
# 12700           115.299510           30.921033
# 12701           115.299510           30.921033
# 12702           115.299510           30.921033
# 12703           115.043710           31.180120
# 12704           115.403080           30.788660
# 12705           115.538660           29.859670
# 12706           114.221990           30.440350
# 12707           115.285650           30.940280
# 12708           114.388530           30.619420
# 12709           114.877060           30.362066
# 12710           115.299983           30.921713
# 12711           115.538660           29.859670
# 12712           115.310844           30.931711
# 12713           115.263890           30.830170
# 12714           114.299193           30.656986
# 12715           114.343559           30.560495
# 12716           115.402770           30.785845
# 12717           115.310844           30.931711
# 12718           115.406400           30.789860
# 12719           114.358005           30.508117
# 12720           114.250820           30.732060
# 12721           115.299983           30.921713
# 12722           115.299510           30.921033
# 12723           115.299510           30.921033
# 12724           115.285650           30.940280
# 12725           115.299510           30.921033
#
# [12726 rows x 4 columns]
# eps= 0.010000000000000002

# %%
xqwz = pd.DataFrame(xq_code_list)
xqwz['east_longitude'] = pd.DataFrame(pre_night_longitude_max_list)
xqwz['west_longitude'] = pd.DataFrame(pre_night_longitude_min_list)
xqwz['north_latitude'] = pd.DataFrame(pre_night_latitude_max_list)
xqwz['south_latitude'] = pd.DataFrame(pre_night_latitude_min_list)

# %%
xqwz.to_csv('D:/data/sun/dbscan/xqwz.csv')
print('end')
# Out:
# end
